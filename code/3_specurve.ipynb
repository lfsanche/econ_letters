# %%
import yaml
import stata_setup
stata_setup.config("C:/Program Files/Stata18/", "se")
# Out:
#   ___  ____  ____  ____  ____ ®
#  /__    /   ____/   /   ____/      StataNow 18.5
# ___/   /   /___/   /   /___/       SE—Standard Edition
#
#  Statistics and Data Science       Copyright 1985-2023 StataCorp LLC
#                                    StataCorp
#                                    4905 Lakeway Drive
#                                    College Station, Texas 77845 USA
#                                    800-782-8272        https://www.stata.com
#                                    979-696-4600        service@stata.com
#
# Stata license: Unlimited-user network, expiring 23 May 2025
# Serial number: 401809312616
#   Licensed to: LFSA
#                ESPOL
#
# Notes:
#       1. Unicode is supported; see help unicode_advice.
#       2. Maximum number of variables is set to 5,000 but can be increased;
#           see help set_maxvar.

# %%
# %%stata
#
# clear all
#
# use "../data/data", clear
#
# egen journal1 = group(journal)
# Out:
# .
# . clear all
#
# .
# . use "../data/data", clear
# .
# . egen journal1 = group(journal)
#
# .

# %% [markdown]
# # Figure 1: Specifcation Curves - F-K grade Readability Score

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    stripped_line = line.strip()
    if stripped_line.startswith("#     - log(F-K grade): log_flesch_kincaid_grade_level"):
        # Uncomment the line
        modified_lines.append(line.replace("#     -", "-"))  # Replace `#-` with `-`
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line uncommented successfully if it was commented!")
# Out:
# Line uncommented successfully if it was commented!

# %% [markdown]
# ## Figure 1 (a)

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    stripped_line = line.strip()
    if stripped_line.startswith("#     - Only female: only_female"):
        # Uncomment the line
        modified_lines.append(line.replace("#     -", "-"))  # Replace `#-` with `-`
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line uncommented successfully if it was commented!")
# Out:
# Line uncommented successfully if it was commented!

# %%
# %%stata
#
# specurve using "readability_graph_specurve.yml"
# Out:
# .
# . specurve using "readability_graph_specurve.yml"
# [specurve] 15:49:30 - 15 total specifications to estimate.
# [specurve] 15:49:30 - Estimating model 1 of 15
# [specurve] 15:49:32 - Estimating model 2 of 15
# [specurve] 15:49:32 - Estimating model 3 of 15
# [specurve] 15:49:32 - Estimating model 4 of 15
# [specurve] 15:49:32 - Estimating model 5 of 15
# [specurve] 15:49:33 - Estimating model 6 of 15
# [specurve] 15:49:33 - Estimating model 7 of 15
# [specurve] 15:49:33 - Estimating model 8 of 15
# [specurve] 15:49:34 - Estimating model 9 of 15
# [specurve] 15:49:34 - Estimating model 10 of 15
# [specurve] 15:49:34 - Estimating model 11 of 15
# [specurve] 15:49:35 - Estimating model 12 of 15
# [specurve] 15:49:36 - Estimating model 13 of 15
# [specurve] 15:49:36 - Estimating model 14 of 15
# [specurve] 15:49:36 - Estimating model 15 of 15
# [specurve] 15:49:37 - 15 out of 15 models have point estimates significant at 1
# > % level.
# [specurve] 15:49:37 - 15 out of 15 models have point estimates significant at 5
# > % level.
# [specurve] 15:49:37 - 15 out of 15 models have point estimates significant at 1
# > 0% level.
# [specurve] 15:49:37 - Plotting specification curve...
# [specurve] 15:49:40 - Completed.
# [specurve] use frame change specurve to see results
# [specurve] use frame change default to switch back to current frame
#
# .

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    if line.strip() == "- Only female: only_female":
        modified_lines.append(f"#     {line}")  # Comment out the line
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line commented successfully!")
# Out:
# Line commented successfully!

# %% [markdown]
# ## Figure 1 (b)

# %%
# %%stata
#
# clear all
#
# use "../data/data", clear
#
# egen journal1 = group(journal)
# Out:
# .
# . clear all
#
# .
# . use "../data/data", clear
#
# .
# . egen journal1 = group(journal)
# .

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    stripped_line = line.strip()
    if stripped_line.startswith("#     - Proportion of women: prop_women"):
        # Uncomment the line
        modified_lines.append(line.replace("#     -", "-"))  # Replace `#-` with `-`
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line uncommented successfully if it was commented!")
# Out:
# Line uncommented successfully if it was commented!

# %%
# %%stata
#
# specurve using "readability_graph_specurve.yml"
# Out:
# .
# . specurve using "readability_graph_specurve.yml"
# [specurve] 15:50:10 - 15 total specifications to estimate.
# [specurve] 15:50:10 - Estimating model 1 of 15
# [specurve] 15:50:11 - Estimating model 2 of 15
# [specurve] 15:50:12 - Estimating model 3 of 15
# [specurve] 15:50:12 - Estimating model 4 of 15
# [specurve] 15:50:12 - Estimating model 5 of 15
# [specurve] 15:50:13 - Estimating model 6 of 15
# [specurve] 15:50:13 - Estimating model 7 of 15
# [specurve] 15:50:13 - Estimating model 8 of 15
# [specurve] 15:50:13 - Estimating model 9 of 15
# [specurve] 15:50:14 - Estimating model 10 of 15
# [specurve] 15:50:14 - Estimating model 11 of 15
# [specurve] 15:50:15 - Estimating model 12 of 15
# [specurve] 15:50:15 - Estimating model 13 of 15
# [specurve] 15:50:15 - Estimating model 14 of 15
# [specurve] 15:50:16 - Estimating model 15 of 15
# [specurve] 15:50:17 - 13 out of 15 models have point estimates significant at 1
# > % level.
# [specurve] 15:50:17 - 15 out of 15 models have point estimates significant at 5
# > % level.
# [specurve] 15:50:17 - 15 out of 15 models have point estimates significant at 1
# > 0% level.
# [specurve] 15:50:17 - Plotting specification curve...
# [specurve] 15:50:18 - Completed.
# [specurve] use frame change specurve to see results
# [specurve] use frame change default to switch back to current frame
#
# .

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    if line.strip() == "- Proportion of women: prop_women":
        modified_lines.append(f"#     {line}")  # Comment out the line
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line commented successfully!")
# Out:
# Line commented successfully!

# %% [markdown]
# ## Figure 1 (c)

# %%
# %%stata
#
# clear all
#
# use "../data/data", clear
#
# egen journal1 = group(journal)
# Out:
# .
# . clear all
#
# .
# . use "../data/data", clear
# .
# . egen journal1 = group(journal)
#
# .

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    stripped_line = line.strip()
    if stripped_line.startswith("#     - Only male: only_male"):
        # Uncomment the line
        modified_lines.append(line.replace("#     -", "-"))  # Replace `#-` with `-`
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line uncommented successfully if it was commented!")
# Out:
# Line uncommented successfully if it was commented!

# %%
# %%stata
#
# specurve using "readability_graph_specurve.yml"
# Out:
# .
# . specurve using "readability_graph_specurve.yml"
# [specurve] 15:50:42 - 15 total specifications to estimate.
# [specurve] 15:50:42 - Estimating model 1 of 15
# [specurve] 15:50:43 - Estimating model 2 of 15
# [specurve] 15:50:43 - Estimating model 3 of 15
# [specurve] 15:50:43 - Estimating model 4 of 15
# [specurve] 15:50:44 - Estimating model 5 of 15
# [specurve] 15:50:44 - Estimating model 6 of 15
# [specurve] 15:50:44 - Estimating model 7 of 15
# [specurve] 15:50:44 - Estimating model 8 of 15
# [specurve] 15:50:45 - Estimating model 9 of 15
# [specurve] 15:50:45 - Estimating model 10 of 15
# [specurve] 15:50:45 - Estimating model 11 of 15
# [specurve] 15:50:46 - Estimating model 12 of 15
# [specurve] 15:50:47 - Estimating model 13 of 15
# [specurve] 15:50:47 - Estimating model 14 of 15
# [specurve] 15:50:47 - Estimating model 15 of 15
# [specurve] 15:50:48 - 15 out of 15 models have point estimates significant at 1
# > % level.
# [specurve] 15:50:48 - 15 out of 15 models have point estimates significant at 5
# > % level.
# [specurve] 15:50:48 - 15 out of 15 models have point estimates significant at 1
# > 0% level.
# [specurve] 15:50:48 - Plotting specification curve...
# [specurve] 15:50:49 - Completed.
# [specurve] use frame change specurve to see results
# [specurve] use frame change default to switch back to current frame
#
# .

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    if line.strip() == "- Only male: only_male":
        modified_lines.append(f"#     {line}")  # Comment out the line
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line commented successfully!")
# Out:
# Line commented successfully!

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    if line.strip() == "- log(F-K grade): log_flesch_kincaid_grade_level":
        modified_lines.append(f"#     {line}")  # Comment out the line
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line commented successfully!")
# Out:
# Line commented successfully!

# %% [markdown]
# # Figure 1: Specifcation Curves - Dale-Chall Readability Score

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    stripped_line = line.strip()
    if stripped_line.startswith("#     - ln(Dale chall): log_dale_chall"):
        # Uncomment the line
        modified_lines.append(line.replace("#     -", "-"))  # Replace `#-` with `-`
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line uncommented successfully if it was commented!")
# Out:
# Line uncommented successfully if it was commented!

# %% [markdown]
# ## Figure 1 (a)

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    stripped_line = line.strip()
    if stripped_line.startswith("#     - Only female: only_female"):
        # Uncomment the line
        modified_lines.append(line.replace("#     -", "-"))  # Replace `#-` with `-`
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line uncommented successfully if it was commented!")
# Out:
# Line uncommented successfully if it was commented!

# %%
# %%stata
#
# specurve using "readability_graph_specurve.yml"
# Out:
# .
# . specurve using "readability_graph_specurve.yml"
# [specurve] 15:51:13 - 15 total specifications to estimate.
# [specurve] 15:51:13 - Estimating model 1 of 15
# [specurve] 15:51:13 - Estimating model 2 of 15
# [specurve] 15:51:14 - Estimating model 3 of 15
# [specurve] 15:51:14 - Estimating model 4 of 15
# [specurve] 15:51:14 - Estimating model 5 of 15
# [specurve] 15:51:14 - Estimating model 6 of 15
# [specurve] 15:51:14 - Estimating model 7 of 15
# [specurve] 15:51:14 - Estimating model 8 of 15
# [specurve] 15:51:15 - Estimating model 9 of 15
# [specurve] 15:51:15 - Estimating model 10 of 15
# [specurve] 15:51:16 - Estimating model 11 of 15
# [specurve] 15:51:16 - Estimating model 12 of 15
# [specurve] 15:51:17 - Estimating model 13 of 15
# [specurve] 15:51:17 - Estimating model 14 of 15
# [specurve] 15:51:17 - Estimating model 15 of 15
# [specurve] 15:51:18 - 14 out of 15 models have point estimates significant at 1
# > % level.
# [specurve] 15:51:18 - 15 out of 15 models have point estimates significant at 5
# > % level.
# [specurve] 15:51:18 - 15 out of 15 models have point estimates significant at 1
# > 0% level.
# [specurve] 15:51:18 - Plotting specification curve...
# [specurve] 15:51:19 - Completed.
# [specurve] use frame change specurve to see results
# [specurve] use frame change default to switch back to current frame
#
# .

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    if line.strip() == "- Only female: only_female":
        modified_lines.append(f"#     {line}")  # Comment out the line
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line commented successfully!")
# Out:
# Line commented successfully!

# %% [markdown]
# ## Figure 1 (b)

# %%
# %%stata
#
# clear all
#
# use "../data/data", clear
#
# global save_tables "../tables/"
#
# egen journal1 = group(journal)
# Out:
# .
# . clear all
#
# .
# . use "../data/data", clear
#
# .
# . global save_tables "../tables/"
#
# .
# . egen journal1 = group(journal)
#
# .

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    stripped_line = line.strip()
    if stripped_line.startswith("#     - Proportion of women: prop_women"):
        # Uncomment the line
        modified_lines.append(line.replace("#     -", "-"))  # Replace `#-` with `-`
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line uncommented successfully if it was commented!")
# Out:
# Line uncommented successfully if it was commented!

# %%
# %%stata
#
# specurve using "readability_graph_specurve.yml"
# Out:
# .
# . specurve using "readability_graph_specurve.yml"
# [specurve] 15:51:33 - 15 total specifications to estimate.
# [specurve] 15:51:33 - Estimating model 1 of 15
# [specurve] 15:51:34 - Estimating model 2 of 15
# [specurve] 15:51:34 - Estimating model 3 of 15
# [specurve] 15:51:34 - Estimating model 4 of 15
# [specurve] 15:51:34 - Estimating model 5 of 15
# [specurve] 15:51:35 - Estimating model 6 of 15
# [specurve] 15:51:35 - Estimating model 7 of 15
# [specurve] 15:51:35 - Estimating model 8 of 15
# [specurve] 15:51:36 - Estimating model 9 of 15
# [specurve] 15:51:37 - Estimating model 10 of 15
# [specurve] 15:51:37 - Estimating model 11 of 15
# [specurve] 15:51:38 - Estimating model 12 of 15
# [specurve] 15:51:39 - Estimating model 13 of 15
# [specurve] 15:51:39 - Estimating model 14 of 15
# [specurve] 15:51:40 - Estimating model 15 of 15
# [specurve] 15:51:40 - 14 out of 15 models have point estimates significant at 1
# > % level.
# [specurve] 15:51:40 - 15 out of 15 models have point estimates significant at 5
# > % level.
# [specurve] 15:51:40 - 15 out of 15 models have point estimates significant at 1
# > 0% level.
# [specurve] 15:51:40 - Plotting specification curve...
# [specurve] 15:51:42 - Completed.
# [specurve] use frame change specurve to see results
# [specurve] use frame change default to switch back to current frame
#
# .

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    if line.strip() == "- Proportion of women: prop_women":
        modified_lines.append(f"#     {line}")  # Comment out the line
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line commented successfully!")
# Out:
# Line commented successfully!

# %% [markdown]
# ## Figure 1 (c)

# %%
# %%stata
#
# clear all
#
# use "../data/data", clear
#
# global save_tables "../tables/"
#
# egen journal1 = group(journal)
# Out:
# .
# . clear all
#
# .
# . use "../data/data", clear
#
# .
# . global save_tables "../tables/"
#
# .
# . egen journal1 = group(journal)
#
# .

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    stripped_line = line.strip()
    if stripped_line.startswith("#     - Only male: only_male"):
        # Uncomment the line
        modified_lines.append(line.replace("#     -", "-"))  # Replace `#-` with `-`
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line uncommented successfully if it was commented!")
# Out:
# Line uncommented successfully if it was commented!

# %%
# %%stata
#
# specurve using "readability_graph_specurve.yml"
# Out:
# .
# . specurve using "readability_graph_specurve.yml"
# [specurve] 15:51:58 - 15 total specifications to estimate.
# [specurve] 15:51:58 - Estimating model 1 of 15
# [specurve] 15:51:59 - Estimating model 2 of 15
# [specurve] 15:52:00 - Estimating model 3 of 15
# [specurve] 15:52:00 - Estimating model 4 of 15
# [specurve] 15:52:00 - Estimating model 5 of 15
# [specurve] 15:52:00 - Estimating model 6 of 15
# [specurve] 15:52:00 - Estimating model 7 of 15
# [specurve] 15:52:00 - Estimating model 8 of 15
# [specurve] 15:52:01 - Estimating model 9 of 15
# [specurve] 15:52:01 - Estimating model 10 of 15
# [specurve] 15:52:01 - Estimating model 11 of 15
# [specurve] 15:52:02 - Estimating model 12 of 15
# [specurve] 15:52:03 - Estimating model 13 of 15
# [specurve] 15:52:03 - Estimating model 14 of 15
# [specurve] 15:52:03 - Estimating model 15 of 15
# [specurve] 15:52:04 - 14 out of 15 models have point estimates significant at 1
# > % level.
# [specurve] 15:52:04 - 15 out of 15 models have point estimates significant at 5
# > % level.
# [specurve] 15:52:04 - 15 out of 15 models have point estimates significant at 1
# > 0% level.
# [specurve] 15:52:04 - Plotting specification curve...
# [specurve] 15:52:05 - Completed.
# [specurve] use frame change specurve to see results
# [specurve] use frame change default to switch back to current frame
#
# .

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    if line.strip() == "- Only male: only_male":
        modified_lines.append(f"#     {line}")  # Comment out the line
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line commented successfully!")
# Out:
# Line commented successfully!

# %%
# File name
file_path = '../code/readability_graph_specurve.yml'

# Read, modify, and save the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Modify the target line
modified_lines = []
for line in lines:
    if line.strip() == "- ln(Dale chall): log_dale_chall":
        modified_lines.append(f"#     {line}")  # Comment out the line
    else:
        modified_lines.append(line)

# Write the modified content back to the file
with open(file_path, 'w') as file:
    file.writelines(modified_lines)

print("Line commented successfully!")
# Out:
# Line commented successfully!
