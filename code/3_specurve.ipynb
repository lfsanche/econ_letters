# %%
import stata_setup
stata_setup.config("C:/Program Files/Stata18/", "se")

# %%
# %%stata
#
# use "../data/data", clear
#
# global save_tables "../tables/"
# Out:
# .
# . use "../data/data", clear
#
# .
# . global save_tables "../tables/"
#
# .

# %%
# %%stata
# egen journal1 = group(journal)
#
# specurve using "readability_graph_specurve.yml", outcmd
# Out:
# . egen journal1 = group(journal)
#
# .
# . specurve using "readability_graph_specurve.yml", outcmd
# [specurve] 09:30:13 - 15 total specifications to estimate.
# [specurve] 09:30:13 - Estimating model 1 of 15
# reghdfe log_dale_chall only_female both_genders log_num_authors log_num_pages j
# > el_flag if (num_words_90_flag==1  | num_words_90_flag==0), absorb(journal1) v
# > ce(cluster cluster)
# [specurve] 09:30:13 - Estimating model 2 of 15
# reghdfe log_dale_chall only_female both_genders log_num_authors log_num_pages j
# > el_flag if (num_words_90_flag==1  | num_words_90_flag==0), absorb(a_imp b_imp
# >  c_imp  e_imp f_imp g_imp h_imp i_imp j_imp k_imp l_imp m_imp n_imp o_imp p_i
# > mp q_imp r_imp y_imp z_imp) vce(cluster cluster)
# [specurve] 09:30:14 - Estimating model 3 of 15
# reghdfe log_dale_chall only_female both_genders log_num_authors log_num_pages j
# > el_flag if (num_words_90_flag==1  | num_words_90_flag==0), absorb(year) vce(c
# > luster cluster)
# ...
