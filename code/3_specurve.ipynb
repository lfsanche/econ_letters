# %%
import stata_setup
stata_setup.config("C:/Program Files/Stata18/", "se")
# Out:
#   ___  ____  ____  ____  ____ ®
#  /__    /   ____/   /   ____/      StataNow 18.5
# ___/   /   /___/   /   /___/       SE—Standard Edition
#
#  Statistics and Data Science       Copyright 1985-2023 StataCorp LLC
#                                    StataCorp
#                                    4905 Lakeway Drive
#                                    College Station, Texas 77845 USA
#                                    800-782-8272        https://www.stata.com
#                                    979-696-4600        service@stata.com
#
# Stata license: Unlimited-user network, expiring 23 May 2025
# Serial number: 401809312616
#   Licensed to: LFSA
#                ESPOL
#
# Notes:
#       1. Unicode is supported; see help unicode_advice.
#       2. Maximum number of variables is set to 5,000 but can be increased;
#           see help set_maxvar.

# %%
# %%stata
#
# use "../data/data", clear
#
# global save_tables "../tables/"
# Out:
# .
# . use "../data/data", clear
#
# .
# . global save_tables "../tables/"
#
# .

# %%
# %%stata
# egen journal1 = group(journal)
#
# specurve using "readability_graph_specurve.yml", outcmd
# Out:
# . egen journal1 = group(journal)
#
# .
# . specurve using "readability_graph_specurve.yml", outcmd
# [specurve] 09:55:33 - 15 total specifications to estimate.
# [specurve] 09:55:33 - Estimating model 1 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(journal1) vce(cluster cluster)
# [specurve] 09:55:34 - Estimating model 2 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(a_imp b_imp c_imp  e_imp f_imp g_imp h_imp i_imp j_imp k_imp l_imp m_imp
# >  n_imp o_imp p_imp q_imp r_imp y_imp z_imp) vce(cluster cluster)
# [specurve] 09:55:34 - Estimating model 3 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(year) vce(cluster cluster)
# [specurve] 09:55:34 - Estimating model 4 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(ib0.cluster) vce(cluster cluster)
# [specurve] 09:55:34 - Estimating model 5 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(journal1  a_imp b_imp c_imp  e_imp f_imp g_imp h_imp i_imp j_imp k_imp l
# > _imp m_imp n_imp o_imp p_imp q_imp r_imp y_imp z_imp) vce(cluster cluster)
# [specurve] 09:55:35 - Estimating model 6 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(journal1  year) vce(cluster cluster)
# [specurve] 09:55:35 - Estimating model 7 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(journal1 ib0.cluster) vce(cluster cluster)
# [specurve] 09:55:35 - Estimating model 8 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(year a_imp b_imp c_imp  e_imp f_imp g_imp h_imp i_imp j_imp k_imp l_imp
# > m_imp n_imp o_imp p_imp q_imp r_imp y_imp z_imp) vce(cluster cluster)
# [specurve] 09:55:35 - Estimating model 9 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(ib0.cluster a_imp b_imp c_imp  e_imp f_imp g_imp h_imp i_imp j_imp k_imp
# >  l_imp m_imp n_imp o_imp p_imp q_imp r_imp y_imp z_imp) vce(cluster cluster)
# [specurve] 09:55:36 - Estimating model 10 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(year ib0.cluster) vce(cluster cluster)
# [specurve] 09:55:36 - Estimating model 11 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(journal1 year  a_imp b_imp c_imp  e_imp f_imp g_imp h_imp i_imp j_imp k_
# > imp l_imp m_imp n_imp o_imp p_imp q_imp r_imp y_imp z_imp) vce(cluster cluste
# > r)
# [specurve] 09:55:37 - Estimating model 12 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(journal1  ib0.cluster a_imp b_imp c_imp  e_imp f_imp g_imp h_imp i_imp j
# > _imp k_imp l_imp m_imp n_imp o_imp p_imp q_imp r_imp y_imp z_imp) vce(cluster
# >  cluster)
# [specurve] 09:55:37 - Estimating model 13 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(journal1 year  ib0.cluster) vce(cluster cluster)
# [specurve] 09:55:37 - Estimating model 14 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(year ib0.cluster a_imp b_imp c_imp  e_imp f_imp g_imp h_imp i_imp j_imp
# > k_imp l_imp m_imp n_imp o_imp p_imp q_imp r_imp y_imp z_imp) vce(cluster clus
# > ter)
# [specurve] 09:55:38 - Estimating model 15 of 15
# reghdfe log_flesch_kincaid_grade_level only_female both_genders log_num_authors
# >  log_num_pages jel_flag if (num_words_90_flag==1  | num_words_90_flag==0), ab
# > sorb(journal1 year  ib0.cluster  a_imp b_imp c_imp  e_imp f_imp g_imp h_imp i
# > _imp j_imp k_imp l_imp m_imp n_imp o_imp p_imp q_imp r_imp y_imp z_imp) vce(c
# > luster cluster)
# [specurve] 09:55:38 - 15 out of 15 models have point estimates significant at 1
# > % level.
# [specurve] 09:55:38 - 15 out of 15 models have point estimates significant at 5
# > % level.
# [specurve] 09:55:38 - 15 out of 15 models have point estimates significant at 1
# > 0% level.
# [specurve] 09:55:38 - Plotting specification curve...
# [specurve] 09:55:40 - Completed.
# [specurve] use frame change specurve to see results
# [specurve] use frame change default to switch back to current frame
#
# .
