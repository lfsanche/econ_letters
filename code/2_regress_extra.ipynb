# %%
import stata_setup
stata_setup.config("C:/Program Files/Stata18/", "se")
# Out:
#   ___  ____  ____  ____  ____ ®
#  /__    /   ____/   /   ____/      StataNow 18.5
# ___/   /   /___/   /   /___/       SE—Standard Edition
#
#  Statistics and Data Science       Copyright 1985-2023 StataCorp LLC
#                                    StataCorp
#                                    4905 Lakeway Drive
#                                    College Station, Texas 77845 USA
#                                    800-782-8272        https://www.stata.com
#                                    979-696-4600        service@stata.com
#
# Stata license: Unlimited-user network, expiring 23 May 2025
# Serial number: 401809312616
#   Licensed to: LFSA
#                ESPOL
#
# Notes:
#       1. Unicode is supported; see help unicode_advice.
#       2. Maximum number of variables is set to 5,000 but can be increased;
#           see help set_maxvar.

# %% [markdown]
# # Load data

# %%
# %%stata
# clear all
#
# use "../data/data", clear
#
# global save_tables "../tables/"
#
# set seed 123456
# Out:
# . clear all
#
# .
# . use "../data/data", clear
#
# .
# . global save_tables "../tables/"
#
# .
# . set seed 123456
#
# .

# %% [markdown]
# # Generate some variables

# %%
# %%stata
#
# # Generata some variables
# gen pages_females = log_num_pages*only_females
# gen pages_males = log_num_pages*only_males
# gen pages_prop = log_num_pages*prop_women
# gen authors_females = log_num_authors*only_females
# gen authors_males = log_num_authors*only_males
# gen authors_prop = log_num_authors*prop_women
# gen words_females = log_num_words*only_females
# gen words_males = log_num_words*only_males
# gen words_prop = log_num_words*prop_women
#
# gen female=.
# replace female=1 if only_females==1
# replace female=0 if only_males==1
#
# quietly tabulate year, generate(y_)
# quietly tabulate cluster, generate(c_)
# Out:
# .
# . # Generata some variables
# Unknown #command
# . gen pages_females = log_num_pages*only_females
#
# . gen pages_males = log_num_pages*only_males
#
# . gen pages_prop = log_num_pages*prop_women
#
# . gen authors_females = log_num_authors*only_females
#
# . gen authors_males = log_num_authors*only_males
#
# . gen authors_prop = log_num_authors*prop_women
#
# . gen words_females = log_num_words*only_females
#
# . gen words_males = log_num_words*only_males
#
# . gen words_prop = log_num_words*prop_women
#
# .
# . gen female=.
# (4,988 missing values generated)
#
# . replace female=1 if only_females==1
# (246 real changes made)
#
# . replace female=0 if only_males==1
# (3,689 real changes made)
#
# .
# . quietly tabulate year, generate(y_)
#
# . quietly tabulate cluster, generate(c_)
#
# .
# .

# %%
# %%stata
#
# # Generate interaction variables: Jel Code imputend/Observed and sex
# local journals  ecm jpe qje res  //aer based category
#
# local jel_imp a_imp b_imp c_imp  e_imp f_imp g_imp h_imp i_imp j_imp k_imp ///
# 		l_imp m_imp n_imp o_imp p_imp q_imp r_imp y_imp z_imp // d based case
#
# local jel_obs a_obs b_obs c_obs  e_obs f_obs g_obs h_obs i_obs j_obs k_obs ///
# 		l_obs m_obs n_obs o_obs p_obs q_obs r_obs y_obs z_obs // d based case
#
# local sex only_females only_males prop_women
#
# foreach y of local jel_imp {
# 	foreach s of local sex{
#
# 		gen `y'_`s'= `y'*`s'
# 	}
# }
#
# foreach y of local jel_obs {
# 	foreach s of local sex{
#
# 		gen `y'_`s'= `y'*`s'
# 	}
# }
#
# local jel_female1 a_imp_only_females b_imp_only_females c_imp_only_females d_imp_only_females ///
# 				e_imp_only_females f_imp_only_females g_imp_only_females h_imp_only_females ///
# 				i_imp_only_females j_imp_only_females k_imp_only_females l_imp_only_females ///
# 				m_imp_only_females n_imp_only_females o_imp_only_females p_imp_only_females ///
# 				q_imp_only_females r_imp_only_females y_imp_only_females z_imp_only_females
#
# local jel_prop1 a_imp_prop_women b_imp_prop_women c_imp_prop_women d_imp_prop_women ///
# 				e_imp_prop_women f_imp_prop_women g_imp_prop_women h_imp_prop_women ///
# 				i_imp_prop_women j_imp_prop_women k_imp_prop_women l_imp_prop_women ///
# 				m_imp_prop_women n_imp_prop_women o_imp_prop_women p_imp_prop_women ///
# 				q_imp_prop_women r_imp_prop_women y_imp_prop_women z_imp_prop_women
#
# local jel_male1 a_imp_only_males b_imp_only_males c_imp_only_males d_imp_only_males ///
# 				e_imp_only_males f_imp_only_males g_imp_only_males h_imp_only_males ///
# 				i_imp_only_males j_imp_only_males k_imp_only_males l_imp_only_males ///
# 				m_imp_only_males n_imp_only_males o_imp_only_males p_imp_only_males ///
# 				q_imp_only_males r_imp_only_males y_imp_only_males z_imp_only_males
#
# local jel_female2 a_obs_only_females b_obs_only_females c_obs_only_females d_obs_only_females ///
# 				e_obs_only_females f_obs_only_females g_obs_only_females h_obs_only_females ///
# 				i_obs_only_females j_obs_only_females k_obs_only_females l_obs_only_females ///
# 				m_obs_only_females n_obs_only_females o_obs_only_females p_obs_only_females ///
# 				q_obs_only_females r_obs_only_females y_obs_only_females z_obs_only_females
#
# local jel_prop2 a_obs_prop_women b_obs_prop_women c_obs_prop_women d_obs_prop_women ///
# 				e_obs_prop_women f_obs_prop_women g_obs_prop_women h_obs_prop_women ///
# 				i_obs_prop_women j_obs_prop_women k_obs_prop_women l_obs_prop_women ///
# 				m_obs_prop_women n_obs_prop_women o_obs_prop_women p_obs_prop_women ///
# 				q_obs_prop_women r_obs_prop_women y_obs_prop_women z_obs_prop_women
#
# local jel_male2 a_obs_only_males b_obs_only_males c_obs_only_males d_obs_only_males ///
# 				e_obs_only_males f_obs_only_males g_obs_only_males h_obs_only_males ///
# 				i_obs_only_males j_obs_only_males k_obs_only_males l_obs_only_males ///
# 				m_obs_only_males n_obs_only_males o_obs_only_males p_obs_only_males ///
# 				q_obs_only_males r_obs_only_males y_obs_only_males z_obs_only_males
# Out:
# .
# . # Generate interaction variables: Jel Code imputend/Observed and sex
# Unknown #command
# . local journals  ecm jpe qje res  //aer based category
#
# .
# . local jel_imp a_imp b_imp c_imp  e_imp f_imp g_imp h_imp i_imp j_imp k_imp //
# > /
# >                 l_imp m_imp n_imp o_imp p_imp q_imp r_imp y_imp z_imp // d ba
# > sed case
#
# .
# . local jel_obs a_obs b_obs c_obs  e_obs f_obs g_obs h_obs i_obs j_obs k_obs //
# > /
# >                 l_obs m_obs n_obs o_obs p_obs q_obs r_obs y_obs z_obs // d ba
# > sed case
#
# .
# . local sex only_females only_males prop_women
#
# .
# . foreach y of local jel_imp {
#   2.         foreach s of local sex{
#   3.
# .                 gen `y'_`s'= `y'*`s'
#   4.         }
#   5. }
#
# .
# . foreach y of local jel_obs {
#   2.         foreach s of local sex{
#   3.
# .                 gen `y'_`s'= `y'*`s'
#   4.         }
#   5. }
#
# .
# . local jel_female1 a_imp_only_females b_imp_only_females c_imp_only_females d_
# > imp_only_females ///
# >                                 e_imp_only_females f_imp_only_females g_imp_o
# > nly_females h_imp_only_females ///
# >                                 i_imp_only_females j_imp_only_females k_imp_o
# > nly_females l_imp_only_females ///
# >                                 m_imp_only_females n_imp_only_females o_imp_o
# > nly_females p_imp_only_females ///
# >                                 q_imp_only_females r_imp_only_females y_imp_o
# > nly_females z_imp_only_females
#
# .
# . local jel_prop1 a_imp_prop_women b_imp_prop_women c_imp_prop_women d_imp_prop
# > _women ///
# >                                 e_imp_prop_women f_imp_prop_women g_imp_prop_
# > women h_imp_prop_women ///
# >                                 i_imp_prop_women j_imp_prop_women k_imp_prop_
# > women l_imp_prop_women ///
# >                                 m_imp_prop_women n_imp_prop_women o_imp_prop_
# > women p_imp_prop_women ///
# >                                 q_imp_prop_women r_imp_prop_women y_imp_prop_
# > women z_imp_prop_women
#
# .
# . local jel_male1 a_imp_only_males b_imp_only_males c_imp_only_males d_imp_only
# > _males ///
# >                                 e_imp_only_males f_imp_only_males g_imp_only_
# > males h_imp_only_males ///
# >                                 i_imp_only_males j_imp_only_males k_imp_only_
# > males l_imp_only_males ///
# >                                 m_imp_only_males n_imp_only_males o_imp_only_
# > males p_imp_only_males ///
# >                                 q_imp_only_males r_imp_only_males y_imp_only_
# > males z_imp_only_males
#
# .
# . local jel_female2 a_obs_only_females b_obs_only_females c_obs_only_females d_
# > obs_only_females ///
# >                                 e_obs_only_females f_obs_only_females g_obs_o
# > nly_females h_obs_only_females ///
# >                                 i_obs_only_females j_obs_only_females k_obs_o
# > nly_females l_obs_only_females ///
# >                                 m_obs_only_females n_obs_only_females o_obs_o
# > nly_females p_obs_only_females ///
# >                                 q_obs_only_females r_obs_only_females y_obs_o
# > nly_females z_obs_only_females
#
# .
# . local jel_prop2 a_obs_prop_women b_obs_prop_women c_obs_prop_women d_obs_prop
# > _women ///
# >                                 e_obs_prop_women f_obs_prop_women g_obs_prop_
# > women h_obs_prop_women ///
# >                                 i_obs_prop_women j_obs_prop_women k_obs_prop_
# > women l_obs_prop_women ///
# >                                 m_obs_prop_women n_obs_prop_women o_obs_prop_
# > women p_obs_prop_women ///
# >                                 q_obs_prop_women r_obs_prop_women y_obs_prop_
# > women z_obs_prop_women
#
# .
# . local jel_male2 a_obs_only_males b_obs_only_males c_obs_only_males d_obs_only
# > _males ///
# >                                 e_obs_only_males f_obs_only_males g_obs_only_
# > males h_obs_only_males ///
# >                                 i_obs_only_males j_obs_only_males k_obs_only_
# > males l_obs_only_males ///
# >                                 m_obs_only_males n_obs_only_males o_obs_only_
# > males p_obs_only_males ///
# >                                 q_obs_only_males r_obs_only_males y_obs_only_
# > males z_obs_only_males
#
# .
# .

# %%
# %%stata
#
# # Relabel variables - This is necessary to get table of summarize statistics
#
# label variable log_flesch_kincaid_grade_level "log(F-K grade)"
# label variable log_dale_chall "log(Dale-Chall)"
# label variable only_females "\hspace{3mm}Female"
# label variable only_males "\hspace{3mm}Male"
# label variable both_genders "\hspace{3mm}Both genders"
# label variable num_authors "\hspace{3mm}Number of authors"
# label variable log_num_authors "\hspace{3mm}log(Number authors)"
# label variable num_words "\hspace{3mm}Number of words"
# label variable log_num_words "\hspace{3mm}log(Number of words)"
# label variable num_pages "\hspace{3mm}Number of pages"
# label variable log_num_pages "\hspace{3mm}log(Number pages)"
# label variable num_sentences "\hspace{3mm}Number of sentences"
# label variable num_syllables "\hspace{3mm}Number of syllables"
# label variable log_num_sentences "\hspace{3mm}log(Number of sentences)"
# label variable log_num_syllables "\hspace{3mm}log(Number of syllables)"
# label variable prop_women "\hspace{3mm}Share of women"
# label variable jel_flag "\hspace{3mm}Papers with  jel code"
# label variable isolated "\hspace{3mm}Papers not connected"
# label variable aer "\hspace{3mm}American Economic Review"
# label variable ecm "\hspace{3mm}Econometrica"
# label variable jpe "\hspace{3mm}Journal of Political Economy"
# label variable qje "\hspace{3mm}The Quarterly Journal of Economics"
# label variable res "\hspace{3mm}Review Economic Studies"
#
# label variable pages_females "\hspace{3mm}log(Number of pages) $\times$ Female"
# label variable pages_males "\hspace{3mm}log(Number of pages) $\times$ Male"
# label variable pages_prop "\hspace{3mm}log(Number of pages) $\times$ Share of females"
# label variable authors_females "\hspace{3mm}log(Number of authors) $\times$ Female"
# label variable authors_males "\hspace{3mm}log(Number of authors) $\times$ Male"
# label variable authors_prop "\hspace{3mm}log(Number of authors) $\time$ Share of females"
# label variable words_females "\hspace{3mm}log(Number of words) $\times$ Female"
# label variable words_males "\hspace{3mm}log(Number of words) $\times$ Male"
# label variable words_prop "\hspace{3mm}log(Number of words) $\time$ Share of females"
# Out:
# .
# . # Relabel variables - This is necessary to get table of summarize statistics
# Unknown #command
# .
# . label variable log_flesch_kincaid_grade_level "log(F-K grade)"
#
# . label variable log_dale_chall "log(Dale-Chall)"
#
# . label variable only_females "\hspace{3mm}Female"
#
# . label variable only_males "\hspace{3mm}Male"
#
# . label variable both_genders "\hspace{3mm}Both genders"
#
# . label variable num_authors "\hspace{3mm}Number of authors"
#
# . label variable log_num_authors "\hspace{3mm}log(Number authors)"
#
# . label variable num_words "\hspace{3mm}Number of words"
#
# . label variable log_num_words "\hspace{3mm}log(Number of words)"
#
# . label variable num_pages "\hspace{3mm}Number of pages"
#
# . label variable log_num_pages "\hspace{3mm}log(Number pages)"
#
# . label variable num_sentences "\hspace{3mm}Number of sentences"
#
# . label variable num_syllables "\hspace{3mm}Number of syllables"
#
# . label variable log_num_sentences "\hspace{3mm}log(Number of sentences)"
#
# . label variable log_num_syllables "\hspace{3mm}log(Number of syllables)"
#
# . label variable prop_women "\hspace{3mm}Share of women"
#
# . label variable jel_flag "\hspace{3mm}Papers with  jel code"
#
# . label variable isolated "\hspace{3mm}Papers not connected"
#
# . label variable aer "\hspace{3mm}American Economic Review"
#
# . label variable ecm "\hspace{3mm}Econometrica"
#
# . label variable jpe "\hspace{3mm}Journal of Political Economy"
#
# . label variable qje "\hspace{3mm}The Quarterly Journal of Economics"
#
# . label variable res "\hspace{3mm}Review Economic Studies"
#
# .
# . label variable pages_females "\hspace{3mm}log(Number of pages) $\times$ Femal
# > e"
#
# . label variable pages_males "\hspace{3mm}log(Number of pages) $\times$ Male"
#
# . label variable pages_prop "\hspace{3mm}log(Number of pages) $\times$ Share of
# >  females"
#
# . label variable authors_females "\hspace{3mm}log(Number of authors) $\times$ F
# > emale"
#
# . label variable authors_males "\hspace{3mm}log(Number of authors) $\times$ Mal
# > e"
#
# . label variable authors_prop "\hspace{3mm}log(Number of authors) $\time$ Share
# >  of females"
#
# . label variable words_females "\hspace{3mm}log(Number of words) $\times$ Femal
# > e"
#
# . label variable words_males "\hspace{3mm}log(Number of words) $\times$ Male"
#
# . label variable words_prop "\hspace{3mm}log(Number of words) $\time$ Share of
# > females"
#
# .
# .

# %%
# %%stata
#
# rename log_flesch_kincaid_grade_level FKG
# rename log_dale_chall DCH
# Out:
# .
# . rename log_flesch_kincaid_grade_level FKG
#
# . rename log_dale_chall DCH
#
# .
# .

# %% [markdown]
# # Table 4. Double-Selection Lasso Linear Estimation Results, JEL codes observed (page 5)

# %%
# %%stata
#
# quietly dsregress FKG  log_num_authors  log_num_pages both_genders only_females if jel_flag==1, ///
# 			controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# 		estadd scalar w1 = e(N)
# 		estadd scalar w2 = e(k_controls)
# 		estadd scalar w3 = e(k_controls_sel)
# 		estadd scalar w4 = e(chi2)
# 		est store m1
#
# quietly dsregress FKG  	log_num_authors  log_num_pages both_genders prop_women if jel_flag==1, ///
# 			controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# 		estadd scalar w1 = e(N)
# 		estadd scalar w2 = e(k_controls)
# 		estadd scalar w3 = e(k_controls_sel)
# 		estadd scalar w4 = e(chi2)
# 		est store m2
#
# quietly dsregress FKG  log_num_authors  log_num_pages both_genders only_males  if jel_flag==1, ///
# 			controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# 		estadd scalar w1 = e(N)
# 		estadd scalar w2 = e(k_controls)
# 		estadd scalar w3 = e(k_controls_sel)
# 		estadd scalar w4 = e(chi2)
# 		est store m3
#
#
# esttab m1 m2 m3  using "$save_tables\dgregress_FKG_JO.tex",  replace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
#  		stats(N k_controls k_controls_sel chi2, label( "Observations" "Number potential controls" ///
#  		"Number controls selected" "$\chi^2(4)$") fmt( 0 0 0 %9.3f)) label
# Out:
# .
# . quietly dsregress FKG  log_num_authors  log_num_pages both_genders only_femal
# > es if jel_flag==1, ///
# >                         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  je
# > l_flag ) vce(cluster cluster) rseed(42)
#
# .
# .                 estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# .                 estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# .                 estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  20
#
# .                 estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  52.270097
#
# .                 est store m1
#
# .
# . quietly dsregress FKG   log_num_authors  log_num_pages both_genders prop_wome
# > n if jel_flag==1, ///
# >                         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  je
# > l_flag ) vce(cluster cluster) rseed(42)
#
# .
# .                 estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# .                 estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# .                 estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  20
#
# .                 estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  50.161103
#
# .                 est store m2
#
# .
# . quietly dsregress FKG  log_num_authors  log_num_pages both_genders only_males
# >   if jel_flag==1, ///
# >                         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  je
# > l_flag ) vce(cluster cluster) rseed(42)
#
# .
# .                 estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# .                 estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# .                 estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  16
#
# .                 estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  51.666484
#
# .                 est store m3
#
# .
# .
# . esttab m1 m2 m3  using "$save_tables\dgregress_FKG_JO.tex",  replace b(4) se(
# > 4) star(* 0.10 ** 0.05) r2   ///
# >                 stats(N k_controls k_controls_sel chi2, label( "Observations"
# >  "Number potential controls" ///
# >                 "Number controls selected" "$\chi^2(4)$") fmt( 0 0 0 %9.3f))
# > label
# (output written to ../tables/\dgregress_FKG_JO.tex)
#
# .
# . estimates table m1 m2 m3, b(%7.4f) se(%7.4f)  stats(N)
#
# --------------------------------------------
#     Variable |   m1        m2        m3
# -------------+------------------------------
# log_num_au~s | -0.0046   -0.0051   -0.0047
#              |  0.0072    0.0070    0.0072
# log_num_pa~s |  0.0218    0.0213    0.0217
#              |  0.0045    0.0045    0.0045
# both_genders | -0.0124   -0.0031    0.0130
#              |  0.0054    0.0071    0.0100
# only_females | -0.0251
#              |  0.0070
#   prop_women |           -0.0218
#              |            0.0069
#   only_males |                      0.0256
#              |                      0.0068
# -------------+------------------------------
#            N |    3126      3126      3126
# --------------------------------------------
#                                 Legend: b/se
#
# .
# .

# %%
# %%stata
# estimates table m1 m2 m3, b(%7.4f) se(%7.4f)  stats(N)
# Out:
# . estimates table m1 m2 m3, b(%7.4f) se(%7.4f)  stats(N)
#
# --------------------------------------------
#     Variable |   m1        m2        m3
# -------------+------------------------------
# log_num_au~s | -0.0046   -0.0051   -0.0047
#              |  0.0072    0.0070    0.0072
# log_num_pa~s |  0.0218    0.0213    0.0217
#              |  0.0045    0.0045    0.0045
# both_genders | -0.0124   -0.0031    0.0130
#              |  0.0054    0.0071    0.0100
# only_females | -0.0251
#              |  0.0070
#   prop_women |           -0.0218
#              |            0.0069
#   only_males |                      0.0256
#              |                      0.0068
# -------------+------------------------------
#            N |    3126      3126      3126
# --------------------------------------------
#                                 Legend: b/se
#
# .
# .

# %% [markdown]
# # Table 5: Double-Selection Lasso Linear Estimation Results with Hyperparameters Chosen by Cross-validation & Adaptive Lasso, JEL codes imputed (page 6)

# %%
# %%stata
#
# dsregress FKG log_num_authors  log_num_pages both_genders only_females  , ///
# 	controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(cluster cluster) ///
# 		selection(cv) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m1
#
# dsregress FKG log_num_authors  log_num_pages both_genders only_females   , ///
# 	controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(cluster cluster) ///
# 		selection(adaptive) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m2
#
# dsregress FKG log_num_authors  log_num_pages both_genders prop_women  , ///
# 	controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(cluster cluster) ///
# 			selection(cv) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m3
#
# dsregress FKG log_num_authors  log_num_pages both_genders prop_women  , ///
# 	controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(cluster cluster) ///
# 		selection(adaptive) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m4
#
# dsregress FKG log_num_authors  log_num_pages both_genders only_males  , ///
# 	controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(cluster cluster) ///
# 		selection(cv) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m5
#
# dsregress FKG log_num_authors  log_num_pages both_genders only_males  , ///
# 	controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(cluster cluster) ///
# 		selection(adaptive) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m6
#
# esttab m1 m2 m3 m4 m5 m6  using "$save_tables\dsregress_sel_FKG_JI.tex",  replace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
# stats(N k_controls k_controls_sel chi2 selection, label( "Observations" "Number potential controls" ///
# "Number controls selected" "$\chi^2(4)$" "Selection") fmt( 0 0 0 %9.3f 0)) label
# Out:
# .
# . dsregress FKG log_num_authors  log_num_pages both_genders only_females  , ///
# >         controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(clus
# > ter cluster) ///
# >                 selection(cv) rseed(42)
#
# Estimating lasso for FKG using cv
# Estimating lasso for log_num_authors using cv
# Estimating lasso for log_num_pages using cv
# Estimating lasso for both_genders using cv
# Estimating lasso for only_females using cv
#
# Double-selection linear model         Number of obs               =      4,988
#                                       Number of controls          =        257
#                                       Number of selected controls =         37
#                                       Wald chi2(4)                =      16.66
#                                       Prob > chi2                 =     0.0023
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0052809   .0042429    -1.24   0.213    -.0135969    .0030351
# log_num_pa~s |   .0162162    .005277     3.07   0.002     .0058735    .0265589
# both_genders |  -.0069556   .0046385    -1.50   0.134     -.016047    .0021357
# only_females |  -.0197148   .0057778    -3.41   0.001    -.0310391   -.0083906
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  37
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  16.65665
#
# . est store m1
#
# .
# . dsregress FKG log_num_authors  log_num_pages both_genders only_females   , //
# > /
# >         controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(clus
# > ter cluster) ///
# >                 selection(adaptive) rseed(42)
#
# Estimating lasso for FKG using adaptive
# Estimating lasso for log_num_authors using adaptive
# Estimating lasso for log_num_pages using adaptive
# Estimating lasso for both_genders using adaptive
# Estimating lasso for only_females using adaptive
#
# Double-selection linear model         Number of obs               =      4,988
#                                       Number of controls          =        257
#                                       Number of selected controls =         29
#                                       Wald chi2(4)                =      15.50
#                                       Prob > chi2                 =     0.0038
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0056156   .0043344    -1.30   0.195    -.0141108    .0028796
# log_num_pa~s |   .0145988   .0049268     2.96   0.003     .0049424    .0242552
# both_genders |  -.0069861   .0048719    -1.43   0.152    -.0165349    .0025627
# only_females |  -.0198133   .0059934    -3.31   0.001    -.0315602   -.0080664
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  29
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  15.497473
#
# . est store m2
#
# .
# . dsregress FKG log_num_authors  log_num_pages both_genders prop_women  , ///
# >         controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(clus
# > ter cluster) ///
# >                         selection(cv) rseed(42)
#
# Estimating lasso for FKG using cv
# Estimating lasso for log_num_authors using cv
# Estimating lasso for log_num_pages using cv
# Estimating lasso for both_genders using cv
# Estimating lasso for prop_women using cv
#
# Double-selection linear model         Number of obs               =      4,988
#                                       Number of controls          =        257
#                                       Number of selected controls =         37
#                                       Wald chi2(4)                =      13.61
#                                       Prob > chi2                 =     0.0087
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0053689   .0042331    -1.27   0.205    -.0136657    .0029278
# log_num_pa~s |   .0161836   .0052931     3.06   0.002     .0058093     .026558
# both_genders |   .0005261   .0042799     0.12   0.902    -.0078624    .0089146
#   prop_women |  -.0172381   .0058155    -2.96   0.003    -.0286363   -.0058398
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  37
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  13.608618
#
# . est store m3
#
# .
# . dsregress FKG log_num_authors  log_num_pages both_genders prop_women  , ///
# >         controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(clus
# > ter cluster) ///
# >                 selection(adaptive) rseed(42)
#
# Estimating lasso for FKG using adaptive
# Estimating lasso for log_num_authors using adaptive
# Estimating lasso for log_num_pages using adaptive
# Estimating lasso for both_genders using adaptive
# Estimating lasso for prop_women using adaptive
#
# Double-selection linear model         Number of obs               =      4,988
#                                       Number of controls          =        257
#                                       Number of selected controls =         28
#                                       Wald chi2(4)                =      11.59
#                                       Prob > chi2                 =     0.0207
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |   -.005642   .0043373    -1.30   0.193     -.014143     .002859
# log_num_pa~s |   .0147835   .0050196     2.95   0.003     .0049452    .0246218
# both_genders |   .0007139   .0043283     0.16   0.869    -.0077695    .0091973
#   prop_women |  -.0177031   .0065294    -2.71   0.007    -.0305006   -.0049056
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  28
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  11.591257
#
# . est store m4
#
# .
# . dsregress FKG log_num_authors  log_num_pages both_genders only_males  , ///
# >         controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(clus
# > ter cluster) ///
# >                 selection(cv) rseed(42)
#
# Estimating lasso for FKG using cv
# Estimating lasso for log_num_authors using cv
# Estimating lasso for log_num_pages using cv
# Estimating lasso for both_genders using cv
# Estimating lasso for only_males using cv
#
# Double-selection linear model         Number of obs               =      4,988
#                                       Number of controls          =        257
#                                       Number of selected controls =         37
#                                       Wald chi2(4)                =      16.66
#                                       Prob > chi2                 =     0.0023
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0052809   .0042429    -1.24   0.213    -.0135969    .0030351
# log_num_pa~s |   .0162162    .005277     3.07   0.002     .0058735    .0265589
# both_genders |   .0127592   .0061882     2.06   0.039     .0006305    .0248879
#   only_males |   .0197148   .0057778     3.41   0.001     .0083906    .0310391
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  37
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  16.65665
#
# . est store m5
#
# .
# . dsregress FKG log_num_authors  log_num_pages both_genders only_males  , ///
# >         controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(clus
# > ter cluster) ///
# >                 selection(adaptive) rseed(42)
#
# Estimating lasso for FKG using adaptive
# Estimating lasso for log_num_authors using adaptive
# Estimating lasso for log_num_pages using adaptive
# Estimating lasso for both_genders using adaptive
# Estimating lasso for only_males using adaptive
#
# Double-selection linear model         Number of obs               =      4,988
#                                       Number of controls          =        257
#                                       Number of selected controls =         29
#                                       Wald chi2(4)                =      14.23
#                                       Prob > chi2                 =     0.0066
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0056131   .0043282    -1.30   0.195    -.0140962    .0028701
# log_num_pa~s |   .0147336    .005024     2.93   0.003     .0048869    .0245804
# both_genders |   .0134498   .0064464     2.09   0.037     .0008151    .0260844
#   only_males |   .0207569   .0064392     3.22   0.001     .0081363    .0333775
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  29
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  14.228264
#
# . est store m6
#
# .
# . esttab m1 m2 m3 m4 m5 m6  using "$save_tables\dsregress_sel_FKG_JI.tex",  rep
# > lace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
# > stats(N k_controls k_controls_sel chi2 selection, label( "Observations" "Numb
# > er potential controls" ///
# > "Number controls selected" "$\chi^2(4)$" "Selection") fmt( 0 0 0 %9.3f 0)) la
# > bel
# (file ../tables/\dsregress_sel_FKG_JI.tex not found)
# (output written to ../tables/\dsregress_sel_FKG_JI.tex)
#
# .

# %%
# %%stata
# estimates table m1 m2 m3 m4 m5 m6, b(%7.4f) se(%7.4f)  stats(N)
# Out:
# --------------------------------------------------------------------------
#     Variable |   m1        m2        m3        m4        m5        m6
# -------------+------------------------------------------------------------
# log_num_au~s | -0.0053   -0.0056   -0.0054   -0.0056   -0.0053   -0.0056
#              |  0.0042    0.0043    0.0042    0.0043    0.0042    0.0043
# log_num_pa~s |  0.0162    0.0146    0.0162    0.0148    0.0162    0.0147
#              |  0.0053    0.0049    0.0053    0.0050    0.0053    0.0050
# both_genders | -0.0070   -0.0070    0.0005    0.0007    0.0128    0.0134
#              |  0.0046    0.0049    0.0043    0.0043    0.0062    0.0064
# only_females | -0.0197   -0.0198
#              |  0.0058    0.0060
#   prop_women |                     -0.0172   -0.0177
#              |                      0.0058    0.0065
#   only_males |                                          0.0197    0.0208
#              |                                          0.0058    0.0064
# -------------+------------------------------------------------------------
#            N |    4988      4988      4988      4988      4988      4988
# --------------------------------------------------------------------------
#                                                               Legend: b/se

# %% [markdown]
# # Table 6: Double-Selection Lasso Linear, Estimation Results with Hyperparameters Chosen by Cross-validation & Adaptive Lasso, JEL codes observed (page 7)

# %%
# %%stata
#
# dsregress FKG log_num_authors  log_num_pages both_genders only_females  if jel_flag==1, ///
# 	controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  ) vce(cluster cluster) ///
# 		selection(cv) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m1
#
# dsregress FKG log_num_authors  log_num_pages both_genders only_females  if jel_flag==1, ///
# 	controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster) ///
# 		selection(adaptive) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m2
#
# dsregress FKG log_num_authors  log_num_pages both_genders prop_women  if jel_flag==1, ///
# 	controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  ) vce(cluster cluster) ///
# 		selection(cv) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m3
#
# dsregress FKG log_num_authors  log_num_pages both_genders prop_women   if jel_flag==1, ///
# 	controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster) ///
# 		selection(adaptive) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m4
#
# dsregress FKG log_num_authors  log_num_pages both_genders only_males  if jel_flag==1, ///
# 	controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  ) vce(cluster cluster) ///
# 		selection(cv) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m5
#
# dsregress FKG log_num_authors  log_num_pages both_genders only_males if jel_flag==1, ////
# 	controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster) ///
# 		selection(adaptive) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m6
#
# esttab m1 m2 m3 m4 m5 m6  using "$save_tables\dsregress_sel_`dvar'_JO.tex",  replace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
# stats(N k_controls k_controls_sel chi2 selection, label( "Observations" "Number potential controls" ///
# "Number controls selected" "$\chi^2(4)$" "Selection") fmt( 0 0 0 %9.3f 0)) label
# Out:
# .
# . dsregress FKG log_num_authors  log_num_pages both_genders only_females  if je
# > l_flag==1, ///
# >         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  ) vce(cluster clus
# > ter) ///
# >                 selection(cv) rseed(42)
#
# Estimating lasso for FKG using cv
# Estimating lasso for log_num_authors using cv
# Estimating lasso for log_num_pages using cv
# Estimating lasso for both_genders using cv
# Estimating lasso for only_females using cv
#
# Double-selection linear model         Number of obs               =      3,126
#                                       Number of controls          =        256
#                                       Number of selected controls =         40
#                                       Wald chi2(4)                =      35.37
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0057113    .006717    -0.85   0.395    -.0188764    .0074537
# log_num_pa~s |   .0192421   .0062775     3.07   0.002     .0069383    .0315458
# both_genders |  -.0106783   .0051566    -2.07   0.038    -.0207851   -.0005716
# only_females |  -.0246884   .0078651    -3.14   0.002    -.0401036   -.0092731
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  40
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  35.369824
#
# . est store m1
#
# .
# . dsregress FKG log_num_authors  log_num_pages both_genders only_females  if je
# > l_flag==1, ///
# >         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster clust
# > er) ///
# >                 selection(adaptive) rseed(42)
#
# Estimating lasso for FKG using adaptive
# Estimating lasso for log_num_authors using adaptive
# Estimating lasso for log_num_pages using adaptive
# Estimating lasso for both_genders using adaptive
# Estimating lasso for only_females using adaptive
#
# Double-selection linear model         Number of obs               =      3,126
#                                       Number of controls          =        256
#                                       Number of selected controls =         30
#                                       Wald chi2(4)                =      32.30
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0052616   .0070784    -0.74   0.457    -.0191351    .0086118
# log_num_pa~s |   .0196512   .0069468     2.83   0.005     .0060357    .0332667
# both_genders |  -.0098022   .0050052    -1.96   0.050    -.0196123    7.79e-06
# only_females |   -.022541   .0074112    -3.04   0.002    -.0370667   -.0080152
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  30
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  32.303758
#
# . est store m2
#
# .
# . dsregress FKG log_num_authors  log_num_pages both_genders prop_women  if jel_
# > flag==1, ///
# >         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  ) vce(cluster clus
# > ter) ///
# >                 selection(cv) rseed(42)
#
# Estimating lasso for FKG using cv
# Estimating lasso for log_num_authors using cv
# Estimating lasso for log_num_pages using cv
# Estimating lasso for both_genders using cv
# Estimating lasso for prop_women using cv
#
# Double-selection linear model         Number of obs               =      3,126
#                                       Number of controls          =        256
#                                       Number of selected controls =         40
#                                       Wald chi2(4)                =      35.84
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |   -.006213   .0065957    -0.94   0.346    -.0191403    .0067142
# log_num_pa~s |   .0191906   .0062733     3.06   0.002      .006895    .0314861
# both_genders |  -.0005898   .0069183    -0.09   0.932    -.0141494    .0129698
#   prop_women |    -.02357   .0073546    -3.20   0.001    -.0379848   -.0091552
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  40
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  35.839164
#
# . est store m3
#
# .
# . dsregress FKG log_num_authors  log_num_pages both_genders prop_women   if jel
# > _flag==1, ///
# >         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster clust
# > er) ///
# >                 selection(adaptive) rseed(42)
#
# Estimating lasso for FKG using adaptive
# Estimating lasso for log_num_authors using adaptive
# Estimating lasso for log_num_pages using adaptive
# Estimating lasso for both_genders using adaptive
# Estimating lasso for prop_women using adaptive
#
# Double-selection linear model         Number of obs               =      3,126
#                                       Number of controls          =        256
#                                       Number of selected controls =         29
#                                       Wald chi2(4)                =      31.54
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0056893   .0069082    -0.82   0.410    -.0192291    .0078505
# log_num_pa~s |   .0197074   .0070809     2.78   0.005     .0058291    .0335858
# both_genders |  -.0005397   .0065131    -0.08   0.934    -.0133051    .0122257
#   prop_women |  -.0216257   .0068989    -3.13   0.002    -.0351474   -.0081041
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  29
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  31.542425
#
# . est store m4
#
# .
# . dsregress FKG log_num_authors  log_num_pages both_genders only_males  if jel_
# > flag==1, ///
# >         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  ) vce(cluster clus
# > ter) ///
# >                 selection(cv) rseed(42)
#
# Estimating lasso for FKG using cv
# Estimating lasso for log_num_authors using cv
# Estimating lasso for log_num_pages using cv
# Estimating lasso for both_genders using cv
# Estimating lasso for only_males using cv
#
# Double-selection linear model         Number of obs               =      3,126
#                                       Number of controls          =        256
#                                       Number of selected controls =         40
#                                       Wald chi2(4)                =      35.37
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0057113    .006717    -0.85   0.395    -.0188764    .0074537
# log_num_pa~s |   .0192421   .0062775     3.07   0.002     .0069383    .0315458
# both_genders |     .01401   .0109705     1.28   0.202    -.0074917    .0355117
#   only_males |   .0246884   .0078651     3.14   0.002     .0092731    .0401036
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  40
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  35.369824
#
# . est store m5
#
# .
# . dsregress FKG log_num_authors  log_num_pages both_genders only_males if jel_f
# > lag==1, ////
# >         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster clust
# > er) ///
# >                 selection(adaptive) rseed(42)
#
# Estimating lasso for FKG using adaptive
# Estimating lasso for log_num_authors using adaptive
# Estimating lasso for log_num_pages using adaptive
# Estimating lasso for both_genders using adaptive
# Estimating lasso for only_males using adaptive
#
# Double-selection linear model         Number of obs               =      3,126
#                                       Number of controls          =        256
#                                       Number of selected controls =         29
#                                       Wald chi2(4)                =      31.54
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0052262    .007011    -0.75   0.456    -.0189676    .0085152
# log_num_pa~s |   .0197522   .0070907     2.79   0.005     .0058546    .0336499
# both_genders |   .0128638   .0101836     1.26   0.207    -.0070958    .0328234
#   only_males |   .0226627   .0073323     3.09   0.002     .0082917    .0370337
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  29
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  31.54104
#
# . est store m6
#
# .
# . esttab m1 m2 m3 m4 m5 m6  using "$save_tables\dsregress_sel_`dvar'_JO.tex",
# > replace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
# > stats(N k_controls k_controls_sel chi2 selection, label( "Observations" "Numb
# > er potential controls" ///
# > "Number controls selected" "$\chi^2(4)$" "Selection") fmt( 0 0 0 %9.3f 0)) la
# > bel
# (file ../tables/\dsregress_sel__JO.tex not found)
# (output written to ../tables/\dsregress_sel__JO.tex)
#
# .
# .

# %%
# %%stata
# estimates table m1 m2 m3 m4 m5 m6, b(%7.4f) se(%7.4f)  stats(N)
# Out:
# --------------------------------------------------------------------------
#     Variable |   m1        m2        m3        m4        m5        m6
# -------------+------------------------------------------------------------
# log_num_au~s | -0.0057   -0.0053   -0.0062   -0.0057   -0.0057   -0.0052
#              |  0.0067    0.0071    0.0066    0.0069    0.0067    0.0070
# log_num_pa~s |  0.0192    0.0197    0.0192    0.0197    0.0192    0.0198
#              |  0.0063    0.0069    0.0063    0.0071    0.0063    0.0071
# both_genders | -0.0107   -0.0098   -0.0006   -0.0005    0.0140    0.0129
#              |  0.0052    0.0050    0.0069    0.0065    0.0110    0.0102
# only_females | -0.0247   -0.0225
#              |  0.0079    0.0074
#   prop_women |                     -0.0236   -0.0216
#              |                      0.0074    0.0069
#   only_males |                                          0.0247    0.0227
#              |                                          0.0079    0.0073
# -------------+------------------------------------------------------------
#            N |    3126      3126      3126      3126      3126      3126
# --------------------------------------------------------------------------
#                                                               Legend: b/se

# %% [markdown]
# # Table 7: Cross-Fit Partialing-Out Lasso Linear Estimation Results, JEL codes imputed (page 8)

# %%
# %%stata
#
# xporegress FKG log_num_authors  log_num_pages both_genders only_females  , ///
#     controls(`journals' `jel_imp' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m1
#
# xporegress FKG log_num_authors  log_num_pages both_genders prop_women   , ///
#     controls(`journals' `jel_imp' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m2
#
# xporegress FKG log_num_authors  log_num_pages both_genders only_males  , ///
#     controls(`journals' `jel_imp' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m3
#
#
# esttab m1 m2 m3  using "$save_tables\xporegress_FKG_JI.tex",  replace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
# stats(N k_controls k_controls_sel chi2, label( "Observations" "Number potential controls" ///
# "Number controls selected" "$\chi^2(4)$") fmt( 0 0 0 %9.3f)) label
# Out:
# .
# . xporegress FKG log_num_authors  log_num_pages both_genders only_females  , //
# > /
# >     controls(`journals' `jel_imp' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster
# >  cluster) rseed(42)
#
# Cross-fit fold 1 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 2 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 3 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 4 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 5 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 6 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 7 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 8 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 9 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 10 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit partialing-out             Number of obs                =      4,988
# linear model                         Number of controls           =        257
#                                      Number of selected controls  =         66
#                                      Number of folds in cross-fit =         10
#                                      Number of resamples          =          1
#                                      Wald chi2(4)                 =      10.45
#                                      Prob > chi2                  =     0.0335
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0056589   .0069977    -0.81   0.419    -.0193742    .0080564
# log_num_pa~s |   .0170889   .0081327     2.10   0.036      .001149    .0330287
# both_genders |   -.007893   .0055429    -1.42   0.154     -.018757     .002971
# only_females |  -.0198142   .0087476    -2.27   0.024    -.0369591   -.0026692
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  66
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  10.451784
#
# . est store m1
#
# .
# . xporegress FKG log_num_authors  log_num_pages both_genders prop_women   , ///
# >     controls(`journals' `jel_imp' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster
# >  cluster) rseed(42)
#
# Cross-fit fold 1 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 2 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 3 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 4 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 5 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 6 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 7 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 8 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 9 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 10 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit partialing-out             Number of obs                =      4,988
# linear model                         Number of controls           =        257
#                                      Number of selected controls  =         67
#                                      Number of folds in cross-fit =         10
#                                      Number of resamples          =          1
#                                      Wald chi2(4)                 =      10.45
#                                      Prob > chi2                  =     0.0335
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0062984   .0070183    -0.90   0.369    -.0200541    .0074572
# log_num_pa~s |   .0171023   .0081231     2.11   0.035     .0011814    .0330233
# both_genders |   .0009799   .0062716     0.16   0.876    -.0113123     .013272
#   prop_women |  -.0209892   .0086643    -2.42   0.015    -.0379709   -.0040075
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  67
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  10.447768
#
# . est store m2
#
# .
# . xporegress FKG log_num_authors  log_num_pages both_genders only_males  , ///
# >     controls(`journals' `jel_imp' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster
# >  cluster) rseed(42)
#
# Cross-fit fold 1 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 2 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 3 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 4 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 5 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 6 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 7 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 8 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 9 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 10 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit partialing-out             Number of obs                =      4,988
# linear model                         Number of controls           =        257
#                                      Number of selected controls  =         67
#                                      Number of folds in cross-fit =         10
#                                      Number of resamples          =          1
#                                      Wald chi2(4)                 =      13.83
#                                      Prob > chi2                  =     0.0079
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0063745   .0069915    -0.91   0.362    -.0200777    .0073286
# log_num_pa~s |   .0174168   .0081146     2.15   0.032     .0015125     .033321
# both_genders |   .0179246   .0101803     1.76   0.078    -.0020285    .0378777
#   only_males |   .0262241   .0088768     2.95   0.003     .0088258    .0436223
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  67
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  13.829693
#
# . est store m3
#
# .
# .
# . esttab m1 m2 m3  using "$save_tables\xporegress_FKG_JI.tex",  replace b(4) se
# > (4) star(* 0.10 ** 0.05) r2   ///
# > stats(N k_controls k_controls_sel chi2, label( "Observations" "Number potenti
# > al controls" ///
# > "Number controls selected" "$\chi^2(4)$") fmt( 0 0 0 %9.3f)) label
# (file ../tables/\xporegress_FKG_JI.tex not found)
# (output written to ../tables/\xporegress_FKG_JI.tex)
#
# .
# .

# %%
# %%stata
# estimates table m1 m2 m3, b(%7.4f) se(%7.4f)  stats(N)
# Out:
# --------------------------------------------
#     Variable |   m1        m2        m3
# -------------+------------------------------
# log_num_au~s | -0.0057   -0.0063   -0.0064
#              |  0.0070    0.0070    0.0070
# log_num_pa~s |  0.0171    0.0171    0.0174
#              |  0.0081    0.0081    0.0081
# both_genders | -0.0079    0.0010    0.0179
#              |  0.0055    0.0063    0.0102
# only_females | -0.0198
#              |  0.0087
#   prop_women |           -0.0210
#              |            0.0087
#   only_males |                      0.0262
#              |                      0.0089
# -------------+------------------------------
#            N |    4988      4988      4988
# --------------------------------------------
#                                 Legend: b/se

# %% [markdown]
# # Table 8: Cross-Fit Partialing-Out Lasso Linear Estimation Results, JEL codes observed (page 9)

# %%
# %%stata
#
# xporegress FKG log_num_authors  log_num_pages both_genders only_females   if jel_flag==1, ///
#     controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster)  rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m1
#
# xporegress FKG log_num_authors  log_num_pages both_genders prop_women   if jel_flag==1, ///
#     controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster)  rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m2
#
# xporegress FKG log_num_authors  log_num_pages both_genders only_males  if jel_flag==1, ///
#     controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster)  rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m3
#
#
# esttab m1 m2 m3  using "$save_tables\xporegress_FKG_JO.tex",  replace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
# stats(N k_controls k_controls_sel chi2, label( "Observations" "Number potential controls" ///
# "Number controls selected" "$\chi^2(4)$") fmt( 0 0 0 %9.3f)) label
# Out:
# .
# . xporegress FKG log_num_authors  log_num_pages both_genders only_females   if
# > jel_flag==1, ///
# >     controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster)
# >  rseed(42)
#
# Cross-fit fold 1 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 2 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 3 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 4 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 5 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 6 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 7 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 8 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 9 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit fold 10 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_females using plugin
#
# Cross-fit partialing-out             Number of obs                =      3,126
# linear model                         Number of controls           =        256
#                                      Number of selected controls  =         59
#                                      Number of folds in cross-fit =         10
#                                      Number of resamples          =          1
#                                      Wald chi2(4)                 =      11.29
#                                      Prob > chi2                  =     0.0235
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0063708   .0068075    -0.94   0.349    -.0197134    .0069717
# log_num_pa~s |   .0191001    .010113     1.89   0.059    -.0007209    .0389211
# both_genders |  -.0124728   .0065699    -1.90   0.058    -.0253497     .000404
# only_females |  -.0274212   .0117675    -2.33   0.020    -.0504851   -.0043574
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  59
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  11.288966
#
# . est store m1
#
# .
# . xporegress FKG log_num_authors  log_num_pages both_genders prop_women   if je
# > l_flag==1, ///
# >     controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster)
# >  rseed(42)
#
# Cross-fit fold 1 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 2 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 3 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 4 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 5 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 6 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 7 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 8 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 9 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit fold 10 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for prop_women using plugin
#
# Cross-fit partialing-out             Number of obs                =      3,126
# linear model                         Number of controls           =        256
#                                      Number of selected controls  =         60
#                                      Number of folds in cross-fit =         10
#                                      Number of resamples          =          1
#                                      Wald chi2(4)                 =      11.49
#                                      Prob > chi2                  =     0.0216
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0068034   .0069113    -0.98   0.325    -.0203494    .0067426
# log_num_pa~s |   .0189398   .0101103     1.87   0.061     -.000876    .0387556
# both_genders |  -.0017406   .0072191    -0.24   0.809    -.0158898    .0124086
#   prop_women |  -.0251741   .0107993    -2.33   0.020    -.0463403   -.0040078
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  60
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  11.488037
#
# . est store m2
#
# .
# . xporegress FKG log_num_authors  log_num_pages both_genders only_males  if jel
# > _flag==1, ///
# >     controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster)
# >  rseed(42)
#
# Cross-fit fold 1 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 2 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 3 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 4 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 5 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 6 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 7 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 8 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 9 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit fold 10 of 10 ...
# Estimating lasso for FKG using plugin
# Estimating lasso for log_num_authors using plugin
# Estimating lasso for log_num_pages using plugin
# Estimating lasso for both_genders using plugin
# Estimating lasso for only_males using plugin
#
# Cross-fit partialing-out             Number of obs                =      3,126
# linear model                         Number of controls           =        256
#                                      Number of selected controls  =         54
#                                      Number of folds in cross-fit =         10
#                                      Number of resamples          =          1
#                                      Wald chi2(4)                 =      10.71
#                                      Prob > chi2                  =     0.0301
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          FKG | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0062401   .0068103    -0.92   0.360    -.0195881    .0071079
# log_num_pa~s |   .0190939   .0101106     1.89   0.059    -.0007224    .0389103
# both_genders |   .0131932   .0117737     1.12   0.262    -.0098828    .0362691
#   only_males |   .0256363   .0115066     2.23   0.026     .0030838    .0481888
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  54
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  10.705604
#
# . est store m3
#
# .
# .
# . esttab m1 m2 m3  using "$save_tables\xporegress FKG_JO.tex",  replace b(4) se
# > (4) star(* 0.10 ** 0.05) r2   ///
# > stats(N k_controls k_controls_sel chi2, label( "Observations" "Number potenti
# > al controls" ///
# > "Number controls selected" "$\chi^2(4)$") fmt( 0 0 0 %9.3f)) label
# (file ../tables/\xporegress FKG_JO.tex not found)
# (output written to ../tables/\xporegress FKG_JO.tex)
#
# .
# .

# %%
# %%stata
# estimates table m1 m2 m3, b(%7.4f) se(%7.4f)  stats(N)
# Out:
# --------------------------------------------
#     Variable |   m1        m2        m3
# -------------+------------------------------
# log_num_au~s | -0.0064   -0.0068   -0.0062
#              |  0.0068    0.0069    0.0068
# log_num_pa~s |  0.0191    0.0189    0.0191
#              |  0.0101    0.0101    0.0101
# both_genders | -0.0125   -0.0017    0.0132
#              |  0.0066    0.0072    0.0118
# only_females | -0.0274
#              |  0.0118
#   prop_women |           -0.0252
#              |            0.0108
#   only_males |                      0.0256
#              |                      0.0115
# -------------+------------------------------
#            N |    3126      3126      3126
# --------------------------------------------
#                                 Legend: b/se

# %% [markdown]
# # Table 9: Double-Selection Lasso Linear Estimation Results, JEL codes imputed (page 11)

# %%
# %%stata
#
# quietly dsregress DCH  log_num_authors  log_num_pages both_genders only_females, ///
# 			controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# 		estadd scalar w1 = e(N)
# 		estadd scalar w2 = e(k_controls)
# 		estadd scalar w3 = e(k_controls_sel)
# 		estadd scalar w4 = e(chi2)
# 		est store m1
#
# quietly dsregress DCH  	log_num_authors  log_num_pages both_genders prop_women, ///
# 			controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# 		estadd scalar w1 = e(N)
# 		estadd scalar w2 = e(k_controls)
# 		estadd scalar w3 = e(k_controls_sel)
# 		estadd scalar w4 = e(chi2)
# 		est store m2
#
# quietly dsregress DCH  log_num_authors  log_num_pages both_genders only_males, ///
# 			controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# 		estadd scalar w1 = e(N)
# 		estadd scalar w2 = e(k_controls)
# 		estadd scalar w3 = e(k_controls_sel)
# 		estadd scalar w4 = e(chi2)
# 		est store m3
#
#
# esttab m1 m2 m3  using "$save_tables\dgregress_DCH_JO.tex",  replace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
#  		stats(N k_controls k_controls_sel chi2, label( "Observations" "Number potential controls" ///
#  		"Number controls selected" "$\chi^2(4)$") fmt( 0 0 0 %9.3f)) label
# Out:
# .
# . quietly dsregress DCH  log_num_authors  log_num_pages both_genders only_femal
# > es, ///
# >                         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  je
# > l_flag ) vce(cluster cluster) rseed(42)
#
# .
# .                 estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# .                 estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# .                 estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  19
#
# .                 estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  183.72541
#
# .                 est store m1
#
# .
# . quietly dsregress DCH   log_num_authors  log_num_pages both_genders prop_wome
# > n, ///
# >                         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  je
# > l_flag ) vce(cluster cluster) rseed(42)
#
# .
# .                 estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# .                 estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# .                 estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  19
#
# .                 estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  141.9422
#
# .                 est store m2
#
# .
# . quietly dsregress DCH  log_num_authors  log_num_pages both_genders only_males
# > , ///
# >                         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  je
# > l_flag ) vce(cluster cluster) rseed(42)
#
# .
# .                 estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# .                 estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# .                 estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  16
#
# .                 estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  171.304
#
# .                 est store m3
#
# .
# .
# . esttab m1 m2 m3  using "$save_tables\dgregress_DCH_JO.tex",  replace b(4) se(
# > 4) star(* 0.10 ** 0.05) r2   ///
# >                 stats(N k_controls k_controls_sel chi2, label( "Observations"
# >  "Number potential controls" ///
# >                 "Number controls selected" "$\chi^2(4)$") fmt( 0 0 0 %9.3f))
# > label
# (file ../tables/\dgregress_DCH_JO.tex not found)
# (output written to ../tables/\dgregress_DCH_JO.tex)
#
# .

# %%
# %%stata
# estimates table m1 m2 m3, b(%7.4f) se(%7.4f)  stats(N)
# Out:
# --------------------------------------------
#     Variable |   m1        m2        m3
# -------------+------------------------------
# log_num_au~s |  0.0001    0.0000    0.0001
#              |  0.0015    0.0015    0.0015
# log_num_pa~s |  0.0281    0.0280    0.0281
#              |  0.0032    0.0032    0.0032
# both_genders | -0.0068   -0.0036    0.0016
#              |  0.0014    0.0017    0.0030
# only_females | -0.0084
#              |  0.0027
#   prop_women |           -0.0076
#              |            0.0025
#   only_males |                      0.0085
#              |                      0.0026
# -------------+------------------------------
#            N |    4988      4988      4988
# --------------------------------------------
#                                 Legend: b/se

# %% [markdown]
# # Table 10: Double-Selection Lasso Linear Estimation Results, JEL codes observed (page 12)

# %%
# %%stata
#
# quietly dsregress DCH    log_num_authors  log_num_pages both_genders only_females if jel_flag==1, ///
# 			controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# 		estadd scalar w1 = e(N)
# 		estadd scalar w2 = e(k_controls)
# 		estadd scalar w3 = e(k_controls_sel)
# 		estadd scalar w4 = e(chi2)
# 		est store m1
#
# quietly dsregress DCH    	log_num_authors  log_num_pages both_genders prop_women if jel_flag==1, ///
# 			controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# 		estadd scalar w1 = e(N)
# 		estadd scalar w2 = e(k_controls)
# 		estadd scalar w3 = e(k_controls_sel)
# 		estadd scalar w4 = e(chi2)
# 		est store m2
#
# quietly dsregress DCH    log_num_authors  log_num_pages both_genders only_males  if jel_flag==1, ///
# 			controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# 		estadd scalar w1 = e(N)
# 		estadd scalar w2 = e(k_controls)
# 		estadd scalar w3 = e(k_controls_sel)
# 		estadd scalar w4 = e(chi2)
# 		est store m3
#
#
# esttab m1 m2 m3  using "$save_tables\dgregress_DCH_JO.tex",  replace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
#  		stats(N k_controls k_controls_sel chi2, label( "Observations" "Number potential controls" ///
#  		"Number controls selected" "$\chi^2(4)$") fmt( 0 0 0 %9.3f)) label
# Out:
# .
# . quietly dsregress DCH    log_num_authors  log_num_pages both_genders only_fem
# > ales if jel_flag==1, ///
# >                         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  je
# > l_flag ) vce(cluster cluster) rseed(42)
#
# .
# .                 estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# .                 estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# .                 estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  22
#
# .                 estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  209.1322
#
# .                 est store m1
#
# .
# . quietly dsregress DCH           log_num_authors  log_num_pages both_genders p
# > rop_women if jel_flag==1, ///
# >                         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  je
# > l_flag ) vce(cluster cluster) rseed(42)
#
# .
# .                 estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# .                 estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# .                 estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  22
#
# .                 estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  195.32076
#
# .                 est store m2
#
# .
# . quietly dsregress DCH    log_num_authors  log_num_pages both_genders only_mal
# > es  if jel_flag==1, ///
# >                         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  je
# > l_flag ) vce(cluster cluster) rseed(42)
#
# .
# .                 estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# .                 estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# .                 estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  18
#
# .                 estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  210.3856
#
# .                 est store m3
#
# .
# .
# . esttab m1 m2 m3  using "$save_tables\dgregress_FKG_JO.tex",  replace b(4) se(
# > 4) star(* 0.10 ** 0.05) r2   ///
# >                 stats(N k_controls k_controls_sel chi2, label( "Observations"
# >  "Number potential controls" ///
# >                 "Number controls selected" "$\chi^2(4)$") fmt( 0 0 0 %9.3f))
# > label
# (output written to ../tables/\dgregress_FKG_JO.tex)
#
# .

# %%
# %%stata
# estimates table m1 m2 m3, b(%7.4f) se(%7.4f)  stats(N)
# Out:
# --------------------------------------------
#     Variable |   m1        m2        m3
# -------------+------------------------------
# log_num_au~s | -0.0005   -0.0005   -0.0004
#              |  0.0016    0.0016    0.0016
# log_num_pa~s |  0.0299    0.0298    0.0300
#              |  0.0022    0.0023    0.0022
# both_genders | -0.0052   -0.0026    0.0020
#              |  0.0014    0.0022    0.0045
# only_females | -0.0086
#              |  0.0041
#   prop_women |           -0.0062
#              |            0.0040
#   only_males |                      0.0073
#              |                      0.0042
# -------------+------------------------------
#            N |    3126      3126      3126
# --------------------------------------------
#                                 Legend: b/se

# %% [markdown]
# # Table 11: Double-Selection Lasso Linear Estimation Results with Hyperparameters Chosen by Cross-validation & Adaptive Lasso, JEL codes imputed (page 13)

# %%
# %%stata
#
# dsregress DCH log_num_authors  log_num_pages both_genders only_females  , ///
# 	controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(cluster cluster) ///
# 		selection(cv) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m1
#
# dsregress DCH log_num_authors  log_num_pages both_genders only_females   , ///
# 	controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(cluster cluster) ///
# 		selection(adaptive) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m2
#
# dsregress DCH log_num_authors  log_num_pages both_genders prop_women  , ///
# 	controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(cluster cluster) ///
# 			selection(cv) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m3
#
# dsregress DCH log_num_authors  log_num_pages both_genders prop_women  , ///
# 	controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(cluster cluster) ///
# 		selection(adaptive) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m4
#
# dsregress DCH log_num_authors  log_num_pages both_genders only_males  , ///
# 	controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(cluster cluster) ///
# 		selection(cv) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m5
#
# dsregress DCH log_num_authors  log_num_pages both_genders only_males  , ///
# 	controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(cluster cluster) ///
# 		selection(adaptive) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m6
#
# esttab m1 m2 m3 m4 m5 m6  using "$save_tables\dsregress_sel_DCH_JI.tex",  replace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
# stats(N k_controls k_controls_sel chi2 selection, label( "Observations" "Number potential controls" ///
# "Number controls selected" "$\chi^2(4)$" "Selection") fmt( 0 0 0 %9.3f 0)) label
# Out:
# .
# . dsregress DCH log_num_authors  log_num_pages both_genders only_females  , ///
# >         controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(clus
# > ter cluster) ///
# >                 selection(cv) rseed(42)
#
# Estimating lasso for DCH using cv
# Estimating lasso for log_num_authors using cv
# Estimating lasso for log_num_pages using cv
# Estimating lasso for both_genders using cv
# Estimating lasso for only_females using cv
#
# Double-selection linear model         Number of obs               =      4,988
#                                       Number of controls          =        257
#                                       Number of selected controls =         37
#                                       Wald chi2(4)                =      80.77
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          DCH | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0016712   .0018883    -0.89   0.376    -.0053722    .0020298
# log_num_pa~s |   .0267179   .0038786     6.89   0.000     .0191159    .0343198
# both_genders |  -.0064277   .0014308    -4.49   0.000    -.0092321   -.0036234
# only_females |   -.008962   .0026667    -3.36   0.001    -.0141886   -.0037354
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  37
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  80.768206
#
# . est store m1
#
# .
# . dsregress DCH log_num_authors  log_num_pages both_genders only_females   , //
# > /
# >         controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(clus
# > ter cluster) ///
# >                 selection(adaptive) rseed(42)
#
# Estimating lasso for DCH using adaptive
# Estimating lasso for log_num_authors using adaptive
# Estimating lasso for log_num_pages using adaptive
# Estimating lasso for both_genders using adaptive
# Estimating lasso for only_females using adaptive
#
# Double-selection linear model         Number of obs               =      4,988
#                                       Number of controls          =        257
#                                       Number of selected controls =         29
#                                       Wald chi2(4)                =      74.11
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          DCH | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0019813   .0018041    -1.10   0.272    -.0055174    .0015547
# log_num_pa~s |    .026172   .0038038     6.88   0.000     .0187167    .0336273
# both_genders |  -.0069757   .0014931    -4.67   0.000    -.0099021   -.0040493
# only_females |  -.0098486    .002711    -3.63   0.000     -.015162   -.0045351
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  29
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  74.10745
#
# . est store m2
#
# .
# . dsregress DCH log_num_authors  log_num_pages both_genders prop_women  , ///
# >         controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(clus
# > ter cluster) ///
# >                         selection(cv) rseed(42)
#
# Estimating lasso for DCH using cv
# Estimating lasso for log_num_authors using cv
# Estimating lasso for log_num_pages using cv
# Estimating lasso for both_genders using cv
# Estimating lasso for prop_women using cv
#
# Double-selection linear model         Number of obs               =      4,988
#                                       Number of controls          =        257
#                                       Number of selected controls =         37
#                                       Wald chi2(4)                =      83.05
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          DCH | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0017297   .0018791    -0.92   0.357    -.0054126    .0019531
# log_num_pa~s |   .0267061   .0038898     6.87   0.000     .0190822    .0343301
# both_genders |  -.0029775   .0013895    -2.14   0.032    -.0057008   -.0002541
#   prop_women |  -.0079567   .0026857    -2.96   0.003    -.0132205   -.0026929
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  37
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  83.053835
#
# . est store m3
#
# .
# . dsregress DCH log_num_authors  log_num_pages both_genders prop_women  , ///
# >         controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(clus
# > ter cluster) ///
# >                 selection(adaptive) rseed(42)
#
# Estimating lasso for DCH using adaptive
# Estimating lasso for log_num_authors using adaptive
# Estimating lasso for log_num_pages using adaptive
# Estimating lasso for both_genders using adaptive
# Estimating lasso for prop_women using adaptive
#
# Double-selection linear model         Number of obs               =      4,988
#                                       Number of controls          =        257
#                                       Number of selected controls =         28
#                                       Wald chi2(4)                =      76.22
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          DCH | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0020824   .0018094    -1.15   0.250    -.0056288     .001464
# log_num_pa~s |   .0259879   .0037464     6.94   0.000     .0186451    .0333308
# both_genders |  -.0033631   .0014132    -2.38   0.017     -.006133   -.0005933
#   prop_women |  -.0083592   .0027427    -3.05   0.002    -.0137349   -.0029836
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  28
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  76.22023
#
# . est store m4
#
# .
# . dsregress DCH log_num_authors  log_num_pages both_genders only_males  , ///
# >         controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(clus
# > ter cluster) ///
# >                 selection(cv) rseed(42)
#
# Estimating lasso for DCH using cv
# Estimating lasso for log_num_authors using cv
# Estimating lasso for log_num_pages using cv
# Estimating lasso for both_genders using cv
# Estimating lasso for only_males using cv
#
# Double-selection linear model         Number of obs               =      4,988
#                                       Number of controls          =        257
#                                       Number of selected controls =         37
#                                       Wald chi2(4)                =      80.77
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          DCH | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0016712   .0018883    -0.89   0.376    -.0053722    .0020298
# log_num_pa~s |   .0267179   .0038786     6.89   0.000     .0191159    .0343198
# both_genders |   .0025343   .0024265     1.04   0.296    -.0022214    .0072901
#   only_males |    .008962   .0026667     3.36   0.001     .0037354    .0141886
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  37
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  80.768206
#
# . est store m5
#
# .
# . dsregress DCH log_num_authors  log_num_pages both_genders only_males  , ///
# >         controls(`journals' `jel_imp' y_2-y_20  c_2-c_215 jel_flag ) vce(clus
# > ter cluster) ///
# >                 selection(adaptive) rseed(42)
#
# Estimating lasso for DCH using adaptive
# Estimating lasso for log_num_authors using adaptive
# Estimating lasso for log_num_pages using adaptive
# Estimating lasso for both_genders using adaptive
# Estimating lasso for only_males using adaptive
#
# Double-selection linear model         Number of obs               =      4,988
#                                       Number of controls          =        257
#                                       Number of selected controls =         29
#                                       Wald chi2(4)                =      75.95
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 215 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          DCH | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0020048   .0018268    -1.10   0.272    -.0055853    .0015757
# log_num_pa~s |   .0260216   .0037338     6.97   0.000     .0187035    .0333397
# both_genders |   .0023911    .002492     0.96   0.337    -.0024932    .0072755
#   only_males |   .0092917   .0027222     3.41   0.001     .0039563    .0146272
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  4988
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  257
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  29
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  75.950252
#
# . est store m6
#
# .
# . esttab m1 m2 m3 m4 m5 m6  using "$save_tables\dsregress_sel_DCH_JI.tex",  rep
# > lace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
# > stats(N k_controls k_controls_sel chi2 selection, label( "Observations" "Numb
# > er potential controls" ///
# > "Number controls selected" "$\chi^2(4)$" "Selection") fmt( 0 0 0 %9.3f 0)) la
# > bel
# (file ../tables/\dsregress_sel_DCH_JI.tex not found)
# (output written to ../tables/\dsregress_sel_DCH_JI.tex)
#
# .

# %%
# %%stata
# estimates table m1 m2 m3 m4 m5 m6, b(%7.4f) se(%7.4f)  stats(N)
# Out:
# --------------------------------------------------------------------------
#     Variable |   m1        m2        m3        m4        m5        m6
# -------------+------------------------------------------------------------
# log_num_au~s | -0.0017   -0.0020   -0.0017   -0.0021   -0.0017   -0.0020
#              |  0.0019    0.0018    0.0019    0.0018    0.0019    0.0018
# log_num_pa~s |  0.0267    0.0262    0.0267    0.0260    0.0267    0.0260
#              |  0.0039    0.0038    0.0039    0.0037    0.0039    0.0037
# both_genders | -0.0064   -0.0070   -0.0030   -0.0034    0.0025    0.0024
#              |  0.0014    0.0015    0.0014    0.0014    0.0024    0.0025
# only_females | -0.0090   -0.0098
#              |  0.0027    0.0027
#   prop_women |                     -0.0080   -0.0084
#              |                      0.0027    0.0027
#   only_males |                                          0.0090    0.0093
#              |                                          0.0027    0.0027
# -------------+------------------------------------------------------------
#            N |    4988      4988      4988      4988      4988      4988
# --------------------------------------------------------------------------
#                                                               Legend: b/se

# %% [markdown]
# # Table 12: Double-Selection Lasso Linear Estimation Results with Hyperparameters Chosen by Cross-validation & Adaptive Lasso, JEL codes observed (page 13)

# %%
# %%stata
#
# dsregress DCH log_num_authors  log_num_pages both_genders only_females  if jel_flag==1, ///
# 	controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  ) vce(cluster cluster) ///
# 		selection(cv) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m1
#
# dsregress DCH log_num_authors  log_num_pages both_genders only_females  if jel_flag==1, ///
# 	controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster) ///
# 		selection(adaptive) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m2
#
# dsregress DCH log_num_authors  log_num_pages both_genders prop_women  if jel_flag==1, ///
# 	controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  ) vce(cluster cluster) ///
# 		selection(cv) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m3
#
# dsregress DCH log_num_authors  log_num_pages both_genders prop_women   if jel_flag==1, ///
# 	controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster) ///
# 		selection(adaptive) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m4
#
# dsregress DCH log_num_authors  log_num_pages both_genders only_males  if jel_flag==1, ///
# 	controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  ) vce(cluster cluster) ///
# 		selection(cv) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m5
#
# dsregress DCH log_num_authors  log_num_pages both_genders only_males if jel_flag==1, ////
# 	controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster) ///
# 		selection(adaptive) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m6
#
# esttab m1 m2 m3 m4 m5 m6  using "$save_tables\dsregress_sel_DCH_JO.tex",  replace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
# stats(N k_controls k_controls_sel chi2 selection, label( "Observations" "Number potential controls" ///
# "Number controls selected" "$\chi^2(4)$" "Selection") fmt( 0 0 0 %9.3f 0)) label
# Out:
# .
# . dsregress DCH log_num_authors  log_num_pages both_genders only_females  if je
# > l_flag==1, ///
# >         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  ) vce(cluster clus
# > ter) ///
# >                 selection(cv) rseed(42)
#
# Estimating lasso for DCH using cv
# Estimating lasso for log_num_authors using cv
# Estimating lasso for log_num_pages using cv
# Estimating lasso for both_genders using cv
# Estimating lasso for only_females using cv
#
# Double-selection linear model         Number of obs               =      3,126
#                                       Number of controls          =        256
#                                       Number of selected controls =         40
#                                       Wald chi2(4)                =      72.94
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          DCH | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0020334   .0018453    -1.10   0.270    -.0056502    .0015833
# log_num_pa~s |    .027027   .0040812     6.62   0.000      .019028    .0350261
# both_genders |  -.0054447   .0015409    -3.53   0.000    -.0084648   -.0024247
# only_females |  -.0094872    .003145    -3.02   0.003    -.0156512   -.0033232
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  40
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  72.939691
#
# . est store m1
#
# .
# . dsregress DCH log_num_authors  log_num_pages both_genders only_females  if je
# > l_flag==1, ///
# >         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster clust
# > er) ///
# >                 selection(adaptive) rseed(42)
#
# Estimating lasso for DCH using adaptive
# Estimating lasso for log_num_authors using adaptive
# Estimating lasso for log_num_pages using adaptive
# Estimating lasso for both_genders using adaptive
# Estimating lasso for only_females using adaptive
#
# Double-selection linear model         Number of obs               =      3,126
#                                       Number of controls          =        256
#                                       Number of selected controls =         30
#                                       Wald chi2(4)                =      69.79
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          DCH | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0019431   .0017243    -1.13   0.260    -.0053227    .0014365
# log_num_pa~s |     .02728   .0044793     6.09   0.000     .0185007    .0360594
# both_genders |  -.0054861   .0015297    -3.59   0.000    -.0084842    -.002488
# only_females |  -.0101395   .0032774    -3.09   0.002    -.0165631   -.0037159
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  30
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  69.791573
#
# . est store m2
#
# .
# . dsregress DCH log_num_authors  log_num_pages both_genders prop_women  if jel_
# > flag==1, ///
# >         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  ) vce(cluster clus
# > ter) ///
# >                 selection(cv) rseed(42)
#
# Estimating lasso for DCH using cv
# Estimating lasso for log_num_authors using cv
# Estimating lasso for log_num_pages using cv
# Estimating lasso for both_genders using cv
# Estimating lasso for prop_women using cv
#
# Double-selection linear model         Number of obs               =      3,126
#                                       Number of controls          =        256
#                                       Number of selected controls =         40
#                                       Wald chi2(4)                =      68.24
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          DCH | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0020385   .0018704    -1.09   0.276    -.0057044    .0016273
# log_num_pa~s |   .0269866   .0040688     6.63   0.000     .0190119    .0349613
# both_genders |  -.0020212   .0018615    -1.09   0.278    -.0056696    .0016273
#   prop_women |  -.0079276   .0030321    -2.61   0.009    -.0138705   -.0019848
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  40
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  68.237241
#
# . est store m3
#
# .
# . dsregress DCH log_num_authors  log_num_pages both_genders prop_women   if jel
# > _flag==1, ///
# >         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster clust
# > er) ///
# >                 selection(adaptive) rseed(42)
#
# Estimating lasso for DCH using adaptive
# Estimating lasso for log_num_authors using adaptive
# Estimating lasso for log_num_pages using adaptive
# Estimating lasso for both_genders using adaptive
# Estimating lasso for prop_women using adaptive
#
# Double-selection linear model         Number of obs               =      3,126
#                                       Number of controls          =        256
#                                       Number of selected controls =         29
#                                       Wald chi2(4)                =      61.23
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          DCH | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0021209   .0017517    -1.21   0.226    -.0055541    .0013124
# log_num_pa~s |    .026861   .0043281     6.21   0.000     .0183781    .0353439
# both_genders |    -.00192   .0019481    -0.99   0.324    -.0057381    .0018982
#   prop_women |  -.0083084   .0031884    -2.61   0.009    -.0145575   -.0020592
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  29
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  61.225048
#
# . est store m4
#
# .
# . dsregress DCH log_num_authors  log_num_pages both_genders only_males  if jel_
# > flag==1, ///
# >         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215  ) vce(cluster clus
# > ter) ///
# >                 selection(cv) rseed(42)
#
# Estimating lasso for DCH using cv
# Estimating lasso for log_num_authors using cv
# Estimating lasso for log_num_pages using cv
# Estimating lasso for both_genders using cv
# Estimating lasso for only_males using cv
#
# Double-selection linear model         Number of obs               =      3,126
#                                       Number of controls          =        256
#                                       Number of selected controls =         40
#                                       Wald chi2(4)                =      72.94
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          DCH | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0020334   .0018453    -1.10   0.270    -.0056502    .0015833
# log_num_pa~s |    .027027   .0040812     6.62   0.000      .019028    .0350261
# both_genders |   .0040425   .0033342     1.21   0.225    -.0024925    .0105774
#   only_males |   .0094872    .003145     3.02   0.003     .0033232    .0156512
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  40
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  72.939691
#
# . est store m5
#
# .
# . dsregress DCH log_num_authors  log_num_pages both_genders only_males if jel_f
# > lag==1, ////
# >         controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster clust
# > er) ///
# >                 selection(adaptive) rseed(42)
#
# Estimating lasso for DCH using adaptive
# Estimating lasso for log_num_authors using adaptive
# Estimating lasso for log_num_pages using adaptive
# Estimating lasso for both_genders using adaptive
# Estimating lasso for only_males using adaptive
#
# Double-selection linear model         Number of obs               =      3,126
#                                       Number of controls          =        256
#                                       Number of selected controls =         29
#                                       Wald chi2(4)                =      66.92
#                                       Prob > chi2                 =     0.0000
#
#                               (Std. err. adjusted for 186 clusters in cluster)
# ------------------------------------------------------------------------------
#              |               Robust
#          DCH | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# log_num_au~s |  -.0020775   .0017264    -1.20   0.229    -.0054611    .0013061
# log_num_pa~s |   .0268966   .0043406     6.20   0.000     .0183892     .035404
# both_genders |   .0041787   .0036544     1.14   0.253    -.0029839    .0113413
#   only_males |   .0096775    .003391     2.85   0.004     .0030313    .0163238
# ------------------------------------------------------------------------------
# Note: Chi-squared test is a Wald test of the coefficients of the variables
#       of interest jointly equal to zero. Lassos select controls for model
#       estimation. Type lassoinfo to see number of selected variables in each
#       lasso.
# Note: Lassos are performed accounting for clusters in cluster.
#
# .
# . estadd scalar w1 = e(N)
#
# added scalar:
#                  e(w1) =  3126
#
# . estadd scalar w2 = e(k_controls)
#
# added scalar:
#                  e(w2) =  256
#
# . estadd scalar w3 = e(k_controls_sel)
#
# added scalar:
#                  e(w3) =  29
#
# . estadd scalar w4 = e(chi2)
#
# added scalar:
#                  e(w4) =  66.921035
#
# . est store m6
#
# .
# . esttab m1 m2 m3 m4 m5 m6  using "$save_tables\dsregress_sel_DCH_JO.tex",  rep
# > lace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
# > stats(N k_controls k_controls_sel chi2 selection, label( "Observations" "Numb
# > er potential controls" ///
# > "Number controls selected" "$\chi^2(4)$" "Selection") fmt( 0 0 0 %9.3f 0)) la
# > bel
# (file ../tables/\dsregress_sel_DCH_JO.tex not found)
# (output written to ../tables/\dsregress_sel_DCH_JO.tex)
#
# .

# %%
# %%stata
# estimates table m1 m2 m3 m4 m5 m6, b(%7.4f) se(%7.4f)  stats(N)
# Out:
# --------------------------------------------------------------------------
#     Variable |   m1        m2        m3        m4        m5        m6
# -------------+------------------------------------------------------------
# log_num_au~s | -0.0020   -0.0019   -0.0020   -0.0021   -0.0020   -0.0021
#              |  0.0018    0.0017    0.0019    0.0018    0.0018    0.0017
# log_num_pa~s |  0.0270    0.0273    0.0270    0.0269    0.0270    0.0269
#              |  0.0041    0.0045    0.0041    0.0043    0.0041    0.0043
# both_genders | -0.0054   -0.0055   -0.0020   -0.0019    0.0040    0.0042
#              |  0.0015    0.0015    0.0019    0.0019    0.0033    0.0037
# only_females | -0.0095   -0.0101
#              |  0.0031    0.0033
#   prop_women |                     -0.0079   -0.0083
#              |                      0.0030    0.0032
#   only_males |                                          0.0095    0.0097
#              |                                          0.0031    0.0034
# -------------+------------------------------------------------------------
#            N |    3126      3126      3126      3126      3126      3126
# --------------------------------------------------------------------------
#                                                               Legend: b/se

# %% [markdown]
# # Table 13: Cross-Fit Partialing-Out Lasso Linear Estimation Results, JEL codes imputed (page 15)

# %%
# %%stata
#
# xporegress DCH log_num_authors  log_num_pages both_genders only_females  , ///
#     controls(`journals' `jel_imp' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m1
#
# xporegress DCH log_num_authors  log_num_pages both_genders prop_women   , ///
#     controls(`journals' `jel_imp' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m2
#
# xporegress DCH log_num_authors  log_num_pages both_genders only_males  , ///
#     controls(`journals' `jel_imp' y_2-y_20  c_2-c_215  jel_flag ) vce(cluster cluster) rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m3
#
#
# esttab m1 m2 m3  using "$save_tables\xporegress_DCH_JI.tex",  replace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
# stats(N k_controls k_controls_sel chi2, label( "Observations" "Number potential controls" ///
# "Number controls selected" "$\chi^2(4)$") fmt( 0 0 0 %9.3f)) label

# %%
# %%stata
# estimates table m1 m2 m3, b(%7.4f) se(%7.4f)  stats(N)

# %% [markdown]
# # Table 14: Cross-Fit Partialing-Out Lasso Linear Estimation Results, JEL codes observed (page 15)

# %%
# %%stata
#
# xporegress DCH log_num_authors  log_num_pages both_genders only_females   if jel_flag==1, ///
#     controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster)  rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m1
#
# xporegress DCH log_num_authors  log_num_pages both_genders prop_women   if jel_flag==1, ///
#     controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster)  rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m2
#
# xporegress DCH log_num_authors  log_num_pages both_genders only_males  if jel_flag==1, ///
#     controls(`journals' `jel_obs' y_2-y_20  c_2-c_215 ) vce(cluster cluster)  rseed(42)
#
# estadd scalar w1 = e(N)
# estadd scalar w2 = e(k_controls)
# estadd scalar w3 = e(k_controls_sel)
# estadd scalar w4 = e(chi2)
# est store m3
#
#
# esttab m1 m2 m3  using "$save_tables\xporegress_DCH_JO.tex",  replace b(4) se(4) star(* 0.10 ** 0.05) r2   ///
# stats(N k_controls k_controls_sel chi2, label( "Observations" "Number potential controls" ///
# "Number controls selected" "$\chi^2(4)$") fmt( 0 0 0 %9.3f)) label

# %%
# %%stata
# estimates table m1 m2 m3, b(%7.4f) se(%7.4f)  stats(N)
